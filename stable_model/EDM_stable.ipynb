# %%
import torch
from torch import nn
from torch.utils.data import Dataset,DataLoader
from sklearn.preprocessing import OneHotEncoder
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import copy

# %% [markdown]
# # Loading, Analyzing and Transforming Data

# %%
DEVICE = 'cuda' if torch.cuda.is_available() else 'cpu'
BASE_PATH_TRAIN = ''
BASE_PATH_TEST = ''

# %%
df_train = pd.read_csv(BASE_PATH_TRAIN)
df_test = pd.read_csv(BASE_PATH_TEST)

# %%
df_train.head()
# Out:
#    rmse_mean  rmse_std  spectral_centroid_mean  spectral_centroid_std  \
# 0   0.235332  0.026495             1051.946600             100.585427
# 1   0.228770  0.033676             1070.286437              80.816581
# 2   0.226299  0.023821             1360.202520              60.369947
# 3   0.086559  0.085427             1510.821407             453.989878
# 4   0.082979  0.074022             1215.704928             431.555006
#
#    spectral_bandwidth_mean  spectral_bandwidth_std  rolloff_mean  rolloff_std  \
# 0              1370.959281               83.231605   1983.042368   171.870662
# 1              1369.265205               80.522645   1983.290828   119.464846
# 2              1698.988729               42.774033   2531.642127   132.529514
# 3              1993.545837              373.650514   2914.933143  1245.966854
# 4              1712.301348              388.379755   2095.429124  1074.247611
#
#    zero_crossing_rate_mean  zero_crossing_rate_std  ...  tonnetz4_std  \
# 0                 0.051014                0.009117  ...      0.063497
# 1                 0.052434                0.009300  ...      0.099821
# 2                 0.068791                0.009082  ...      0.050842
# 3                 0.055337                0.018990  ...      0.272185
# 4                 0.043280                0.013200  ...      0.125701
#
#    tonnetz5_mean  tonnetz5_std  tonnetz6_mean  tonnetz6_std  chroma_cqt_mean  \
# 0       0.011261      0.022174      -0.003420      0.020674         0.363720
# 1       0.014858      0.031751      -0.044123      0.025047         0.373004
# 2       0.031071      0.027402       0.002164      0.018851         0.636473
# 3      -0.021059      0.068133       0.041426      0.097910         0.408626
# 4      -0.095658      0.092349      -0.116562      0.025237         0.294634
#
#    chroma_cqt_std  spectral_contrast_mean  spectral_contrast_std    label
# 0        0.272265               22.644232              11.780977  ambient
# 1        0.272607               23.334553              11.330307  ambient
# 2        0.181836               19.827988              12.566806  ambient
# 3        0.268816               20.136745              10.750138  ambient
# 4        0.296929               22.229635              10.648263  ambient
#
# [5 rows x 131 columns]

# %%
X_train = df_train.to_numpy()[:,:130]
y_train = df_train.to_numpy()[:,130:]
X_test = df_test.to_numpy()[:,:130]
y_test = df_test.to_numpy()[:,130:]

# %%
count_labels_train, count_values_train = np.unique(y_train, return_counts=True)
count_labels_test, count_values_test = np.unique(y_test, return_counts=True)

fig, (ax1,ax2) = plt.subplots(1,2)
fig.suptitle('LABELS OCCURENCY')
ax1.bar(count_labels_train,count_values_train)
ax1.tick_params(labelrotation=90)
ax1.set_ylabel('QUANTITY')
ax1.set_title('TRAIN')
ax2.bar(count_labels_test,count_values_test)
ax2.tick_params(labelrotation=90)
ax2.set_ylabel('QUANTITY')
ax2.set_title('TEST')
# Out:
# Text(0.5, 1.0, 'TEST')

# %%
encoder = OneHotEncoder() # One-Hot encode for best results
encoder.fit(y_train)
y_train = encoder.transform(y_train).toarray()
y_test = encoder.transform(y_test).toarray()

# %%
len(encoder.categories_[0])
# Out:
# 16

# %%
X_train = torch.from_numpy(X_train.astype(np.float32))
y_train = torch.from_numpy(y_train.astype(np.float32))
X_test = torch.from_numpy(X_test.astype(np.float32))
y_test = torch.from_numpy(y_test.astype(np.float32))

# %%
class EDMDataset(Dataset):
  def __init__(self,inputs,outputs):
    self.inputs = inputs
    self.outputs = outputs

  def __len__(self):
    return len(self.outputs)

  def __getitem__(self,idx):
    input = self.inputs[idx]
    output = self.outputs[idx]
    return input, output

# %%
X_train.shape, X_test.shape
# Out:
# (torch.Size([32000, 130]), torch.Size([8000, 130]))

# %%
torch.manual_seed(42)
train_dataloader = DataLoader(EDMDataset(X_train,y_train),batch_size=3200,shuffle=True)
test_dataloader = DataLoader(EDMDataset(X_test,y_test),batch_size=800,shuffle=True)

# %% [markdown]
# # Creating Model

# %%
class EDMModel(nn.Module):
  def __init__(self):
    super().__init__()
    self.layers = nn.Sequential(
        nn.Linear(130,130),
        nn.LeakyReLU(inplace=True),
        nn.Linear(130,130),
        nn.LeakyReLU(inplace=True),
        nn.Linear(130,16),
    )

  def forward(self,x):
    return self.layers(x)

# %%
torch.manual_seed(42)
model = EDMModel().to(DEVICE)
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(lr=0.00005,params=model.parameters())
EPOCHS = 1000

# %% [markdown]
# # Train and Test Loops

# %%
def train_loop(dataloader,model,loss_fn,optimizer):
  global DEVICE

  model.train()
  for X,y in dataloader:
    X, y = X.to(DEVICE), y.to(DEVICE)
    logits = model(X)
    loss = loss_fn(logits,y)
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

# %%
def test_loop(dataloader,model,loss_fn):
  global DEVICE
  batches = len(dataloader)
  size = len(dataloader.dataset)
  count_loss, count_acc = 0, 0
  model.eval()
  with torch.no_grad():
    for X, y in dataloader:
      X, y = X.to(DEVICE), y.to(DEVICE)
      logits = model(X)
      preds = torch.softmax(logits,dim=1).argmax(dim=1)
      count_loss += loss_fn(logits,y).item()
      count_acc += (preds == y.argmax(dim=1)).sum().item()

  avg_loss = count_loss / batches
  avg_acc = count_acc / size
  print(f'AVG_LOSS:{avg_loss} -- AVG_ACC:{avg_acc*100}')
  return avg_loss, avg_acc

# %% [markdown]
# # Training and Evaluating the model

# %%
losses = []
accs = []

best_acc = 0
best_weights = None

for epoch in range(EPOCHS):
  print(f'EPOCH:{epoch+1}')
  train_loop(train_dataloader,model,loss_fn,optimizer)
  loss, acc = test_loop(test_dataloader,model,loss_fn)

  if acc > best_acc:
    best_acc = acc
    best_weights = copy.deepcopy(model.state_dict())

  losses.append(loss)
  accs.append(acc)
print('DONE!')
model.load_state_dict(best_weights)
print(f'BEST_ACC: {best_acc*100}')
response = input('Do you want to save the model? [y/n]:').upper()
if response == 'Y':
  torch.save(model,'EDMModel_best.pth')
# Out:
# EPOCH:1
# AVG_LOSS:50.00582771301269 -- AVG_ACC:7.9375
# EPOCH:2
# AVG_LOSS:39.88357734680176 -- AVG_ACC:10.2875
# EPOCH:3
# AVG_LOSS:31.23242931365967 -- AVG_ACC:14.512500000000001
# EPOCH:4
# AVG_LOSS:24.83360710144043 -- AVG_ACC:9.2875
# EPOCH:5
# AVG_LOSS:19.16215286254883 -- AVG_ACC:13.275
# EPOCH:6
# AVG_LOSS:14.661302757263183 -- AVG_ACC:8.987499999999999
# EPOCH:7
# AVG_LOSS:11.160175037384032 -- AVG_ACC:14.3625
# EPOCH:8
# AVG_LOSS:8.965180587768554 -- AVG_ACC:17.825
# EPOCH:9
# AVG_LOSS:6.905914306640625 -- AVG_ACC:17.25
# EPOCH:10
# AVG_LOSS:5.062145805358886 -- AVG_ACC:17.3625
# EPOCH:11
# AVG_LOSS:4.327838563919068 -- AVG_ACC:16.287499999999998
# EPOCH:12
# AVG_LOSS:3.7979640483856203 -- AVG_ACC:20.3
# EPOCH:13
# AVG_LOSS:3.6205142974853515 -- AVG_ACC:21.8
# EPOCH:14
# AVG_LOSS:3.45638370513916 -- AVG_ACC:23.825
# EPOCH:15
# AVG_LOSS:3.353670930862427 -- AVG_ACC:24.5
# EPOCH:16
# AVG_LOSS:3.255671167373657 -- AVG_ACC:25.5
# EPOCH:17
# AVG_LOSS:3.1676941871643067 -- AVG_ACC:25.687500000000004
# EPOCH:18
# AVG_LOSS:3.0906816482543946 -- AVG_ACC:26.2625
# EPOCH:19
# AVG_LOSS:3.0325084686279298 -- AVG_ACC:26.787499999999998
# EPOCH:20
# AVG_LOSS:2.966725254058838 -- AVG_ACC:27.200000000000003
# EPOCH:21
# AVG_LOSS:2.899593448638916 -- AVG_ACC:27.712500000000002
# EPOCH:22
# AVG_LOSS:2.8257205963134764 -- AVG_ACC:28.1375
# EPOCH:23
# AVG_LOSS:2.7632566690444946 -- AVG_ACC:28.3375
# EPOCH:24
# AVG_LOSS:2.702591133117676 -- AVG_ACC:28.725
# EPOCH:25
# AVG_LOSS:2.653311276435852 -- AVG_ACC:28.9375
# EPOCH:26
# AVG_LOSS:2.6066163063049315 -- AVG_ACC:29.312500000000004
# EPOCH:27
# AVG_LOSS:2.5613740205764772 -- AVG_ACC:29.625
# EPOCH:28
# AVG_LOSS:2.5296679735183716 -- AVG_ACC:29.9875
# EPOCH:29
# AVG_LOSS:2.494974446296692 -- AVG_ACC:30.425
# EPOCH:30
# AVG_LOSS:2.469039058685303 -- AVG_ACC:31.1
# EPOCH:31
# AVG_LOSS:2.4439780712127686 -- AVG_ACC:31.2125
# EPOCH:32
# AVG_LOSS:2.420169138908386 -- AVG_ACC:31.55
# EPOCH:33
# AVG_LOSS:2.3955668210983276 -- AVG_ACC:32.7125
# EPOCH:34
# AVG_LOSS:2.3759751081466676 -- AVG_ACC:33.425
# EPOCH:35
# AVG_LOSS:2.3500077724456787 -- AVG_ACC:33.5
# EPOCH:36
# AVG_LOSS:2.333884048461914 -- AVG_ACC:34.825
# EPOCH:37
# AVG_LOSS:2.316749620437622 -- AVG_ACC:35.112500000000004
# EPOCH:38
# AVG_LOSS:2.301112413406372 -- AVG_ACC:35.1625
# EPOCH:39
# AVG_LOSS:2.2793368339538573 -- AVG_ACC:35.375
# EPOCH:40
# AVG_LOSS:2.2677663564682007 -- AVG_ACC:36.55
# EPOCH:41
# AVG_LOSS:2.254649806022644 -- AVG_ACC:37.175000000000004
# EPOCH:42
# AVG_LOSS:2.237372708320618 -- AVG_ACC:37.125
# EPOCH:43
# AVG_LOSS:2.2201564073562623 -- AVG_ACC:36.875
# EPOCH:44
# AVG_LOSS:2.2052163600921633 -- AVG_ACC:37.1875
# EPOCH:45
# AVG_LOSS:2.1942931175231934 -- AVG_ACC:37.512499999999996
# EPOCH:46
# AVG_LOSS:2.189713716506958 -- AVG_ACC:38.1
# EPOCH:47
# AVG_LOSS:2.1682814359664917 -- AVG_ACC:38.6125
# EPOCH:48
# AVG_LOSS:2.156369161605835 -- AVG_ACC:38.1875
# EPOCH:49
# AVG_LOSS:2.154387950897217 -- AVG_ACC:37.8
# EPOCH:50
# AVG_LOSS:2.1362618923187258 -- AVG_ACC:38.4375
# EPOCH:51
# AVG_LOSS:2.12586133480072 -- AVG_ACC:38.9375
# EPOCH:52
# AVG_LOSS:2.115084481239319 -- AVG_ACC:38.85
# EPOCH:53
# AVG_LOSS:2.102530288696289 -- AVG_ACC:39.2625
# EPOCH:54
# AVG_LOSS:2.0881200313568113 -- AVG_ACC:39.4875
# EPOCH:55
# AVG_LOSS:2.0776698350906373 -- AVG_ACC:39.2625
# EPOCH:56
# AVG_LOSS:2.0536620259284972 -- AVG_ACC:39.875
# EPOCH:57
# AVG_LOSS:2.047374999523163 -- AVG_ACC:40.575
# EPOCH:58
# AVG_LOSS:2.0433351516723635 -- AVG_ACC:40.400000000000006
# EPOCH:59
# AVG_LOSS:2.0233771443367004 -- AVG_ACC:40.0625
# EPOCH:60
# AVG_LOSS:2.019638550281525 -- AVG_ACC:40.8
# EPOCH:61
# AVG_LOSS:2.018922472000122 -- AVG_ACC:40.4375
# EPOCH:62
# AVG_LOSS:2.008381652832031 -- AVG_ACC:40.5625
# EPOCH:63
# AVG_LOSS:1.9960994958877563 -- AVG_ACC:40.8375
# EPOCH:64
# AVG_LOSS:1.986495888233185 -- AVG_ACC:40.4625
# EPOCH:65
# AVG_LOSS:1.9813067317008972 -- AVG_ACC:40.575
# EPOCH:66
# AVG_LOSS:1.9770725846290589 -- AVG_ACC:40.862500000000004
# EPOCH:67
# AVG_LOSS:1.9708008766174316 -- AVG_ACC:40.925
# EPOCH:68
# AVG_LOSS:1.965036976337433 -- AVG_ACC:40.9625
# EPOCH:69
# AVG_LOSS:1.9506295800209046 -- AVG_ACC:41.3
# EPOCH:70
# AVG_LOSS:1.9495654582977295 -- AVG_ACC:42.3625
# EPOCH:71
# AVG_LOSS:1.9417484283447266 -- AVG_ACC:42.112500000000004
# EPOCH:72
# AVG_LOSS:1.9346850514411926 -- AVG_ACC:41.949999999999996
# EPOCH:73
# AVG_LOSS:1.9376194715499877 -- AVG_ACC:41.4375
# EPOCH:74
# AVG_LOSS:1.9330725431442262 -- AVG_ACC:41.462500000000006
# EPOCH:75
# AVG_LOSS:1.9199316859245301 -- AVG_ACC:41.575
# EPOCH:76
# AVG_LOSS:1.9187545418739318 -- AVG_ACC:41.362500000000004
# EPOCH:77
# AVG_LOSS:1.9067794322967528 -- AVG_ACC:42.4
# EPOCH:78
# AVG_LOSS:1.8933689832687377 -- AVG_ACC:42.975
# EPOCH:79
# AVG_LOSS:1.8805596232414246 -- AVG_ACC:43.05
# EPOCH:80
# AVG_LOSS:1.8849949598312379 -- AVG_ACC:42.775
# EPOCH:81
# AVG_LOSS:1.8811073541641234 -- AVG_ACC:43.1
# EPOCH:82
# AVG_LOSS:1.8784408211708068 -- AVG_ACC:43.125
# EPOCH:83
# AVG_LOSS:1.8759809255599975 -- AVG_ACC:43.625
# EPOCH:84
# AVG_LOSS:1.8646995544433593 -- AVG_ACC:42.9875
# EPOCH:85
# AVG_LOSS:1.8622646093368531 -- AVG_ACC:43.0375
# EPOCH:86
# AVG_LOSS:1.8574775099754333 -- AVG_ACC:43.675000000000004
# EPOCH:87
# AVG_LOSS:1.8504777431488038 -- AVG_ACC:43.575
# EPOCH:88
# AVG_LOSS:1.844877791404724 -- AVG_ACC:44.262499999999996
# EPOCH:89
# AVG_LOSS:1.8433726906776429 -- AVG_ACC:43.5625
# EPOCH:90
# AVG_LOSS:1.8376903295516969 -- AVG_ACC:43.3875
# EPOCH:91
# AVG_LOSS:1.837342095375061 -- AVG_ACC:44.2
# EPOCH:92
# AVG_LOSS:1.8302278757095336 -- AVG_ACC:44.5125
# EPOCH:93
# AVG_LOSS:1.8189978361129762 -- AVG_ACC:44.837500000000006
# EPOCH:94
# AVG_LOSS:1.8164047002792358 -- AVG_ACC:44.6125
# EPOCH:95
# AVG_LOSS:1.8081156730651855 -- AVG_ACC:45.0625
# EPOCH:96
# AVG_LOSS:1.8106871366500854 -- AVG_ACC:45.025
# EPOCH:97
# AVG_LOSS:1.806756865978241 -- AVG_ACC:44.4625
# EPOCH:98
# AVG_LOSS:1.799252200126648 -- AVG_ACC:45.4
# EPOCH:99
# AVG_LOSS:1.7958395838737489 -- AVG_ACC:44.6125
# EPOCH:100
# AVG_LOSS:1.7927985429763793 -- AVG_ACC:45.3625
# EPOCH:101
# AVG_LOSS:1.785436224937439 -- AVG_ACC:45.074999999999996
# EPOCH:102
# AVG_LOSS:1.7871437549591065 -- AVG_ACC:45.7625
# EPOCH:103
# AVG_LOSS:1.7755243301391601 -- AVG_ACC:45.574999999999996
# EPOCH:104
# AVG_LOSS:1.7723048329353333 -- AVG_ACC:45.9125
# EPOCH:105
# AVG_LOSS:1.7704725384712219 -- AVG_ACC:45.7625
# EPOCH:106
# AVG_LOSS:1.763813054561615 -- AVG_ACC:45.875
# EPOCH:107
# AVG_LOSS:1.7655812978744507 -- AVG_ACC:45.175
# EPOCH:108
# AVG_LOSS:1.7597290396690368 -- AVG_ACC:45.875
# EPOCH:109
# AVG_LOSS:1.7617825269699097 -- AVG_ACC:45.637499999999996
# EPOCH:110
# AVG_LOSS:1.7569738626480103 -- AVG_ACC:45.725
# EPOCH:111
# AVG_LOSS:1.7484943151474 -- AVG_ACC:46.0625
# EPOCH:112
# AVG_LOSS:1.7449615955352784 -- AVG_ACC:46.175
# EPOCH:113
# AVG_LOSS:1.7423669457435609 -- AVG_ACC:46.362500000000004
# EPOCH:114
# AVG_LOSS:1.7272600889205934 -- AVG_ACC:46.6875
# EPOCH:115
# AVG_LOSS:1.7377666115760804 -- AVG_ACC:46.675
# EPOCH:116
# AVG_LOSS:1.7317318201065064 -- AVG_ACC:46.637499999999996
# EPOCH:117
# AVG_LOSS:1.7253684639930724 -- AVG_ACC:46.675
# EPOCH:118
# AVG_LOSS:1.7249554634094237 -- AVG_ACC:47.075
# EPOCH:119
# AVG_LOSS:1.7181711792945862 -- AVG_ACC:47.2375
# EPOCH:120
# AVG_LOSS:1.714664912223816 -- AVG_ACC:46.9
# EPOCH:121
# AVG_LOSS:1.7154314637184143 -- AVG_ACC:47.0375
# EPOCH:122
# AVG_LOSS:1.7104004502296448 -- AVG_ACC:47.387499999999996
# EPOCH:123
# AVG_LOSS:1.705490279197693 -- AVG_ACC:47.375
# EPOCH:124
# AVG_LOSS:1.7016030073165893 -- AVG_ACC:47.5375
# EPOCH:125
# AVG_LOSS:1.6991212606430053 -- AVG_ACC:47.25
# EPOCH:126
# AVG_LOSS:1.6939435005187988 -- AVG_ACC:47.6875
# EPOCH:127
# AVG_LOSS:1.686443269252777 -- AVG_ACC:47.8875
# EPOCH:128
# AVG_LOSS:1.6882117867469788 -- AVG_ACC:47.1625
# EPOCH:129
# AVG_LOSS:1.6788407921791078 -- AVG_ACC:47.362500000000004
# EPOCH:130
# AVG_LOSS:1.6773566126823425 -- AVG_ACC:48.1625
# EPOCH:131
# AVG_LOSS:1.6786280512809753 -- AVG_ACC:47.7625
# EPOCH:132
# AVG_LOSS:1.6714077472686768 -- AVG_ACC:48.362500000000004
# EPOCH:133
# AVG_LOSS:1.6719724416732789 -- AVG_ACC:47.9375
# EPOCH:134
# AVG_LOSS:1.6586818814277648 -- AVG_ACC:48.949999999999996
# EPOCH:135
# AVG_LOSS:1.6638428092002868 -- AVG_ACC:48.212500000000006
# EPOCH:136
# AVG_LOSS:1.670705008506775 -- AVG_ACC:48.5
# EPOCH:137
# AVG_LOSS:1.6578410983085632 -- AVG_ACC:48.212500000000006
# EPOCH:138
# AVG_LOSS:1.6511976957321166 -- AVG_ACC:48.75
# EPOCH:139
# AVG_LOSS:1.6500995993614196 -- AVG_ACC:48.212500000000006
# EPOCH:140
# AVG_LOSS:1.6454633116722106 -- AVG_ACC:48.75
# EPOCH:141
# AVG_LOSS:1.6433686137199401 -- AVG_ACC:48.6375
# EPOCH:142
# AVG_LOSS:1.6468591928482055 -- AVG_ACC:49.5625
# EPOCH:143
# AVG_LOSS:1.6357566475868226 -- AVG_ACC:48.925000000000004
# EPOCH:144
# AVG_LOSS:1.635482704639435 -- AVG_ACC:48.875
# EPOCH:145
# AVG_LOSS:1.6446771383285523 -- AVG_ACC:48.6875
# EPOCH:146
# AVG_LOSS:1.6395667672157288 -- AVG_ACC:48.662499999999994
# EPOCH:147
# AVG_LOSS:1.624869132041931 -- AVG_ACC:48.8
# EPOCH:148
# AVG_LOSS:1.62617347240448 -- AVG_ACC:49.5625
# EPOCH:149
# AVG_LOSS:1.6230178833007813 -- AVG_ACC:49.9
# EPOCH:150
# AVG_LOSS:1.6175325512886047 -- AVG_ACC:49.8
# EPOCH:151
# AVG_LOSS:1.619726836681366 -- AVG_ACC:50.3625
# EPOCH:152
# AVG_LOSS:1.61170836687088 -- AVG_ACC:48.9875
# EPOCH:153
# AVG_LOSS:1.6160858988761901 -- AVG_ACC:50.5125
# EPOCH:154
# AVG_LOSS:1.6099700808525086 -- AVG_ACC:49.7875
# EPOCH:155
# AVG_LOSS:1.6120500326156617 -- AVG_ACC:50.18749999999999
# EPOCH:156
# AVG_LOSS:1.610639226436615 -- AVG_ACC:50.175000000000004
# EPOCH:157
# AVG_LOSS:1.6006033897399903 -- AVG_ACC:50.275000000000006
# EPOCH:158
# AVG_LOSS:1.6031600832939148 -- AVG_ACC:49.675000000000004
# EPOCH:159
# AVG_LOSS:1.5946755886077881 -- AVG_ACC:50.9375
# EPOCH:160
# AVG_LOSS:1.592893397808075 -- AVG_ACC:50.4375
# EPOCH:161
# AVG_LOSS:1.5969756245613098 -- AVG_ACC:50.4125
# EPOCH:162
# AVG_LOSS:1.5846582889556884 -- AVG_ACC:50.449999999999996
# EPOCH:163
# AVG_LOSS:1.583405900001526 -- AVG_ACC:50.4625
# EPOCH:164
# AVG_LOSS:1.5866248846054076 -- AVG_ACC:50.175000000000004
# EPOCH:165
# AVG_LOSS:1.580589723587036 -- AVG_ACC:50.625
# EPOCH:166
# AVG_LOSS:1.580503809452057 -- AVG_ACC:50.5625
# EPOCH:167
# AVG_LOSS:1.5787837982177735 -- AVG_ACC:51.0625
# EPOCH:168
# AVG_LOSS:1.573528814315796 -- AVG_ACC:50.4625
# EPOCH:169
# AVG_LOSS:1.5669813752174377 -- AVG_ACC:51.05
# EPOCH:170
# AVG_LOSS:1.5812236785888671 -- AVG_ACC:51.24999999999999
# EPOCH:171
# AVG_LOSS:1.5715680480003358 -- AVG_ACC:51.5625
# EPOCH:172
# AVG_LOSS:1.569685125350952 -- AVG_ACC:51.387499999999996
# EPOCH:173
# AVG_LOSS:1.5564629435539246 -- AVG_ACC:51.9
# EPOCH:174
# AVG_LOSS:1.5678924202919007 -- AVG_ACC:51.71249999999999
# EPOCH:175
# AVG_LOSS:1.5541104078292847 -- AVG_ACC:51.737500000000004
# EPOCH:176
# AVG_LOSS:1.5528487682342529 -- AVG_ACC:51.625
# EPOCH:177
# AVG_LOSS:1.5552096009254455 -- AVG_ACC:52.0
# EPOCH:178
# AVG_LOSS:1.5580906867980957 -- AVG_ACC:51.65
# EPOCH:179
# AVG_LOSS:1.5513060808181762 -- AVG_ACC:51.81249999999999
# EPOCH:180
# AVG_LOSS:1.5461829900741577 -- AVG_ACC:51.9
# EPOCH:181
# AVG_LOSS:1.5519834637641907 -- AVG_ACC:52.0875
# EPOCH:182
# AVG_LOSS:1.5529629468917847 -- AVG_ACC:51.787499999999994
# EPOCH:183
# AVG_LOSS:1.547018563747406 -- AVG_ACC:52.1375
# EPOCH:184
# AVG_LOSS:1.5511345624923707 -- AVG_ACC:51.2625
# EPOCH:185
# AVG_LOSS:1.5374046921730042 -- AVG_ACC:51.74999999999999
# EPOCH:186
# AVG_LOSS:1.539948046207428 -- AVG_ACC:52.0375
# EPOCH:187
# AVG_LOSS:1.5310407638549806 -- AVG_ACC:52.55
# EPOCH:188
# AVG_LOSS:1.5313610196113587 -- AVG_ACC:51.225
# EPOCH:189
# AVG_LOSS:1.524481976032257 -- AVG_ACC:52.87500000000001
# EPOCH:190
# AVG_LOSS:1.5217846870422362 -- AVG_ACC:52.9625
# EPOCH:191
# AVG_LOSS:1.5310194492340088 -- AVG_ACC:52.387499999999996
# EPOCH:192
# AVG_LOSS:1.5349354028701783 -- AVG_ACC:52.949999999999996
# EPOCH:193
# AVG_LOSS:1.5144227027893067 -- AVG_ACC:52.7
# EPOCH:194
# AVG_LOSS:1.5233580708503722 -- AVG_ACC:53.15
# EPOCH:195
# AVG_LOSS:1.5165284276008606 -- AVG_ACC:52.949999999999996
# EPOCH:196
# AVG_LOSS:1.5233107686042786 -- AVG_ACC:52.887499999999996
# EPOCH:197
# AVG_LOSS:1.513742733001709 -- AVG_ACC:53.449999999999996
# EPOCH:198
# AVG_LOSS:1.5095847129821778 -- AVG_ACC:53.4875
# EPOCH:199
# AVG_LOSS:1.5095566630363464 -- AVG_ACC:52.925
# EPOCH:200
# AVG_LOSS:1.5098725318908692 -- AVG_ACC:52.775000000000006
# EPOCH:201
# AVG_LOSS:1.5125160217285156 -- AVG_ACC:52.87500000000001
# EPOCH:202
# AVG_LOSS:1.5075031518936157 -- AVG_ACC:53.325
# EPOCH:203
# AVG_LOSS:1.5057345151901245 -- AVG_ACC:53.5375
# EPOCH:204
# AVG_LOSS:1.492706847190857 -- AVG_ACC:53.37499999999999
# EPOCH:205
# AVG_LOSS:1.50427303314209 -- AVG_ACC:52.7625
# EPOCH:206
# AVG_LOSS:1.487897276878357 -- AVG_ACC:53.325
# EPOCH:207
# AVG_LOSS:1.5066534876823425 -- AVG_ACC:53.0375
# EPOCH:208
# AVG_LOSS:1.490668034553528 -- AVG_ACC:53.1
# EPOCH:209
# AVG_LOSS:1.4891368269920349 -- AVG_ACC:53.362500000000004
# EPOCH:210
# AVG_LOSS:1.4853055000305175 -- AVG_ACC:53.9875
# EPOCH:211
# AVG_LOSS:1.4861065745353699 -- AVG_ACC:53.25
# EPOCH:212
# AVG_LOSS:1.4867302894592285 -- AVG_ACC:53.474999999999994
# EPOCH:213
# AVG_LOSS:1.4775506138801575 -- AVG_ACC:53.362500000000004
# EPOCH:214
# AVG_LOSS:1.4874263167381288 -- AVG_ACC:53.5
# EPOCH:215
# AVG_LOSS:1.4792935013771058 -- AVG_ACC:54.2125
# EPOCH:216
# AVG_LOSS:1.4742154121398925 -- AVG_ACC:53.974999999999994
# EPOCH:217
# AVG_LOSS:1.482860517501831 -- AVG_ACC:53.387499999999996
# EPOCH:218
# AVG_LOSS:1.4769035220146178 -- AVG_ACC:53.825
# EPOCH:219
# AVG_LOSS:1.4733799934387206 -- AVG_ACC:54.15
# EPOCH:220
# AVG_LOSS:1.4784960389137267 -- AVG_ACC:53.349999999999994
# EPOCH:221
# AVG_LOSS:1.467347538471222 -- AVG_ACC:53.87499999999999
# EPOCH:222
# AVG_LOSS:1.472121572494507 -- AVG_ACC:53.862500000000004
# EPOCH:223
# AVG_LOSS:1.4653138875961305 -- AVG_ACC:53.87499999999999
# EPOCH:224
# AVG_LOSS:1.4644927978515625 -- AVG_ACC:54.2875
# EPOCH:225
# AVG_LOSS:1.4826985001564026 -- AVG_ACC:54.362500000000004
# EPOCH:226
# AVG_LOSS:1.4676140904426576 -- AVG_ACC:54.3125
# EPOCH:227
# AVG_LOSS:1.4745641708374024 -- AVG_ACC:53.900000000000006
# EPOCH:228
# AVG_LOSS:1.46618492603302 -- AVG_ACC:54.225
# EPOCH:229
# AVG_LOSS:1.4674884557724 -- AVG_ACC:53.5875
# EPOCH:230
# AVG_LOSS:1.4548460245132446 -- AVG_ACC:54.425000000000004
# EPOCH:231
# AVG_LOSS:1.4536271572113038 -- AVG_ACC:54.65
# EPOCH:232
# AVG_LOSS:1.4619973421096801 -- AVG_ACC:54.15
# EPOCH:233
# AVG_LOSS:1.4592419624328614 -- AVG_ACC:54.65
# EPOCH:234
# AVG_LOSS:1.462187159061432 -- AVG_ACC:54.175
# EPOCH:235
# AVG_LOSS:1.4477916479110717 -- AVG_ACC:55.0625
# EPOCH:236
# AVG_LOSS:1.441122817993164 -- AVG_ACC:55.074999999999996
# EPOCH:237
# AVG_LOSS:1.4529894948005677 -- AVG_ACC:55.025
# EPOCH:238
# AVG_LOSS:1.454943871498108 -- AVG_ACC:54.85
# EPOCH:239
# AVG_LOSS:1.445844292640686 -- AVG_ACC:55.362500000000004
# EPOCH:240
# AVG_LOSS:1.4371716260910035 -- AVG_ACC:55.4875
# EPOCH:241
# AVG_LOSS:1.4527105927467345 -- AVG_ACC:54.449999999999996
# EPOCH:242
# AVG_LOSS:1.4421555519104003 -- AVG_ACC:54.574999999999996
# EPOCH:243
# AVG_LOSS:1.4383155941963195 -- AVG_ACC:55.0875
# EPOCH:244
# AVG_LOSS:1.4449462413787841 -- AVG_ACC:54.43750000000001
# EPOCH:245
# AVG_LOSS:1.4385334134101868 -- AVG_ACC:55.4875
# EPOCH:246
# AVG_LOSS:1.4392317414283753 -- AVG_ACC:55.4875
# EPOCH:247
# AVG_LOSS:1.4328365683555604 -- AVG_ACC:55.2375
# EPOCH:248
# AVG_LOSS:1.4294811367988587 -- AVG_ACC:55.625
# EPOCH:249
# AVG_LOSS:1.4259876370429994 -- AVG_ACC:55.00000000000001
# EPOCH:250
# AVG_LOSS:1.412513756752014 -- AVG_ACC:55.425000000000004
# EPOCH:251
# AVG_LOSS:1.4295900464057922 -- AVG_ACC:55.300000000000004
# EPOCH:252
# AVG_LOSS:1.4222461462020874 -- AVG_ACC:55.43749999999999
# EPOCH:253
# AVG_LOSS:1.4276095986366273 -- AVG_ACC:55.725
# EPOCH:254
# AVG_LOSS:1.4220532298088073 -- AVG_ACC:55.325
# EPOCH:255
# AVG_LOSS:1.4232018828392028 -- AVG_ACC:55.8375
# EPOCH:256
# AVG_LOSS:1.4203506231307983 -- AVG_ACC:55.375
# EPOCH:257
# AVG_LOSS:1.4178608655929565 -- AVG_ACC:55.85
# EPOCH:258
# AVG_LOSS:1.428522026538849 -- AVG_ACC:56.15
# EPOCH:259
# AVG_LOSS:1.406526780128479 -- AVG_ACC:56.012499999999996
# EPOCH:260
# AVG_LOSS:1.40853613615036 -- AVG_ACC:56.637499999999996
# EPOCH:261
# AVG_LOSS:1.4041264057159424 -- AVG_ACC:55.8125
# EPOCH:262
# AVG_LOSS:1.4036181807518004 -- AVG_ACC:56.675
# EPOCH:263
# AVG_LOSS:1.3947583436965942 -- AVG_ACC:56.9125
# EPOCH:264
# AVG_LOSS:1.406443965435028 -- AVG_ACC:56.6625
# EPOCH:265
# AVG_LOSS:1.400039052963257 -- AVG_ACC:56.325
# EPOCH:266
# AVG_LOSS:1.402104377746582 -- AVG_ACC:56.375
# EPOCH:267
# AVG_LOSS:1.3909120321273805 -- AVG_ACC:56.65
# EPOCH:268
# AVG_LOSS:1.3947445273399353 -- AVG_ACC:56.35
# EPOCH:269
# AVG_LOSS:1.397836685180664 -- AVG_ACC:56.2375
# EPOCH:270
# AVG_LOSS:1.391924250125885 -- AVG_ACC:55.675
# EPOCH:271
# AVG_LOSS:1.396733045578003 -- AVG_ACC:56.675
# EPOCH:272
# AVG_LOSS:1.3848665356636047 -- AVG_ACC:56.43749999999999
# EPOCH:273
# AVG_LOSS:1.3883108973503113 -- AVG_ACC:56.85
# EPOCH:274
# AVG_LOSS:1.4005313873291017 -- AVG_ACC:56.0875
# EPOCH:275
# AVG_LOSS:1.3942615985870361 -- AVG_ACC:56.2875
# EPOCH:276
# AVG_LOSS:1.3799074292182922 -- AVG_ACC:56.537499999999994
# EPOCH:277
# AVG_LOSS:1.395481014251709 -- AVG_ACC:55.8125
# EPOCH:278
# AVG_LOSS:1.3748416900634766 -- AVG_ACC:56.987500000000004
# EPOCH:279
# AVG_LOSS:1.3834641218185424 -- AVG_ACC:56.925000000000004
# EPOCH:280
# AVG_LOSS:1.392679512500763 -- AVG_ACC:56.06250000000001
# EPOCH:281
# AVG_LOSS:1.3936261415481568 -- AVG_ACC:56.825
# EPOCH:282
# AVG_LOSS:1.3809762597084045 -- AVG_ACC:56.45
# EPOCH:283
# AVG_LOSS:1.3854122877120971 -- AVG_ACC:56.39999999999999
# EPOCH:284
# AVG_LOSS:1.376162314414978 -- AVG_ACC:56.962500000000006
# EPOCH:285
# AVG_LOSS:1.3706452965736389 -- AVG_ACC:56.862500000000004
# EPOCH:286
# AVG_LOSS:1.3878172755241394 -- AVG_ACC:56.39999999999999
# EPOCH:287
# AVG_LOSS:1.3786720871925353 -- AVG_ACC:57.099999999999994
# EPOCH:288
# AVG_LOSS:1.3649083375930786 -- AVG_ACC:56.89999999999999
# EPOCH:289
# AVG_LOSS:1.383001410961151 -- AVG_ACC:56.95
# EPOCH:290
# AVG_LOSS:1.371547770500183 -- AVG_ACC:57.225
# EPOCH:291
# AVG_LOSS:1.3661709785461427 -- AVG_ACC:56.637499999999996
# EPOCH:292
# AVG_LOSS:1.372741448879242 -- AVG_ACC:57.275
# EPOCH:293
# AVG_LOSS:1.3641716480255126 -- AVG_ACC:57.087500000000006
# EPOCH:294
# AVG_LOSS:1.3701224207878113 -- AVG_ACC:57.35
# EPOCH:295
# AVG_LOSS:1.3635846495628356 -- AVG_ACC:56.725
# EPOCH:296
# AVG_LOSS:1.369554591178894 -- AVG_ACC:57.587500000000006
# EPOCH:297
# AVG_LOSS:1.3647021770477294 -- AVG_ACC:56.962500000000006
# EPOCH:298
# AVG_LOSS:1.3701314330101013 -- AVG_ACC:57.462500000000006
# EPOCH:299
# AVG_LOSS:1.3556352019309998 -- AVG_ACC:57.65
# EPOCH:300
# AVG_LOSS:1.3669761896133423 -- AVG_ACC:57.7125
# EPOCH:301
# AVG_LOSS:1.36005756855011 -- AVG_ACC:56.925000000000004
# EPOCH:302
# AVG_LOSS:1.3554052710533142 -- AVG_ACC:57.225
# EPOCH:303
# AVG_LOSS:1.3548932194709777 -- AVG_ACC:58.175
# EPOCH:304
# AVG_LOSS:1.3568596959114074 -- AVG_ACC:57.525000000000006
# EPOCH:305
# AVG_LOSS:1.3528008460998535 -- AVG_ACC:57.375
# EPOCH:306
# AVG_LOSS:1.346990740299225 -- AVG_ACC:57.8875
# EPOCH:307
# AVG_LOSS:1.3423335075378418 -- AVG_ACC:57.9125
# EPOCH:308
# AVG_LOSS:1.3531120538711547 -- AVG_ACC:57.375
# EPOCH:309
# AVG_LOSS:1.343606913089752 -- AVG_ACC:57.637499999999996
# EPOCH:310
# AVG_LOSS:1.3448778867721558 -- AVG_ACC:57.75
# EPOCH:311
# AVG_LOSS:1.3466273307800294 -- AVG_ACC:57.574999999999996
# EPOCH:312
# AVG_LOSS:1.3519403219223023 -- AVG_ACC:57.05
# EPOCH:313
# AVG_LOSS:1.3451239228248597 -- AVG_ACC:57.8875
# EPOCH:314
# AVG_LOSS:1.3557523012161254 -- AVG_ACC:57.5125
# EPOCH:315
# AVG_LOSS:1.3462571263313294 -- AVG_ACC:57.2625
# EPOCH:316
# AVG_LOSS:1.3319823622703553 -- AVG_ACC:58.375
# EPOCH:317
# AVG_LOSS:1.3600616455078125 -- AVG_ACC:56.987500000000004
# EPOCH:318
# AVG_LOSS:1.336606466770172 -- AVG_ACC:57.99999999999999
# EPOCH:319
# AVG_LOSS:1.3370562314987182 -- AVG_ACC:57.7875
# EPOCH:320
# AVG_LOSS:1.3343978643417358 -- AVG_ACC:57.637499999999996
# EPOCH:321
# AVG_LOSS:1.3458274126052856 -- AVG_ACC:57.199999999999996
# EPOCH:322
# AVG_LOSS:1.3317193269729615 -- AVG_ACC:57.8625
# EPOCH:323
# AVG_LOSS:1.3376519799232482 -- AVG_ACC:58.12500000000001
# EPOCH:324
# AVG_LOSS:1.3477713823318482 -- AVG_ACC:57.6875
# EPOCH:325
# AVG_LOSS:1.322567093372345 -- AVG_ACC:58.5125
# EPOCH:326
# AVG_LOSS:1.3286831378936768 -- AVG_ACC:57.7125
# EPOCH:327
# AVG_LOSS:1.335400390625 -- AVG_ACC:57.587500000000006
# EPOCH:328
# AVG_LOSS:1.3349148392677308 -- AVG_ACC:57.775
# EPOCH:329
# AVG_LOSS:1.338950765132904 -- AVG_ACC:58.137499999999996
# EPOCH:330
# AVG_LOSS:1.3601807951927185 -- AVG_ACC:56.95
# EPOCH:331
# AVG_LOSS:1.3186392545700074 -- AVG_ACC:57.99999999999999
# EPOCH:332
# AVG_LOSS:1.3287840962409974 -- AVG_ACC:57.9375
# EPOCH:333
# AVG_LOSS:1.3353766202926636 -- AVG_ACC:57.7625
# EPOCH:334
# AVG_LOSS:1.3352304816246032 -- AVG_ACC:57.1125
# EPOCH:335
# AVG_LOSS:1.3145279169082642 -- AVG_ACC:58.199999999999996
# EPOCH:336
# AVG_LOSS:1.3306020379066468 -- AVG_ACC:57.462500000000006
# EPOCH:337
# AVG_LOSS:1.3264682412147522 -- AVG_ACC:57.637499999999996
# EPOCH:338
# AVG_LOSS:1.3228777170181274 -- AVG_ACC:58.6875
# EPOCH:339
# AVG_LOSS:1.3289628624916077 -- AVG_ACC:58.175
# EPOCH:340
# AVG_LOSS:1.315078854560852 -- AVG_ACC:58.087500000000006
# EPOCH:341
# AVG_LOSS:1.317229449748993 -- AVG_ACC:58.425000000000004
# EPOCH:342
# AVG_LOSS:1.3313089251518249 -- AVG_ACC:57.550000000000004
# EPOCH:343
# AVG_LOSS:1.3253327012062073 -- AVG_ACC:58.2875
# EPOCH:344
# AVG_LOSS:1.3195535659790039 -- AVG_ACC:58.06249999999999
# EPOCH:345
# AVG_LOSS:1.3172544956207275 -- AVG_ACC:57.8125
# EPOCH:346
# AVG_LOSS:1.3172629356384278 -- AVG_ACC:58.3
# EPOCH:347
# AVG_LOSS:1.3238512516021728 -- AVG_ACC:58.06249999999999
# EPOCH:348
# AVG_LOSS:1.3127147197723388 -- AVG_ACC:58.475
# EPOCH:349
# AVG_LOSS:1.3049196600914001 -- AVG_ACC:58.375
# EPOCH:350
# AVG_LOSS:1.3127691388130187 -- AVG_ACC:58.550000000000004
# EPOCH:351
# AVG_LOSS:1.308268165588379 -- AVG_ACC:58.6875
# EPOCH:352
# AVG_LOSS:1.3122106075286866 -- AVG_ACC:58.85
# EPOCH:353
# AVG_LOSS:1.3051482319831849 -- AVG_ACC:58.8875
# EPOCH:354
# AVG_LOSS:1.3227272510528565 -- AVG_ACC:57.825
# EPOCH:355
# AVG_LOSS:1.3151768803596497 -- AVG_ACC:57.875
# EPOCH:356
# AVG_LOSS:1.3080511689186096 -- AVG_ACC:58.637499999999996
# EPOCH:357
# AVG_LOSS:1.3038769006729125 -- AVG_ACC:58.85
# EPOCH:358
# AVG_LOSS:1.3120789289474488 -- AVG_ACC:58.75
# EPOCH:359
# AVG_LOSS:1.3172202825546264 -- AVG_ACC:58.6125
# EPOCH:360
# AVG_LOSS:1.3220037937164306 -- AVG_ACC:58.262499999999996
# EPOCH:361
# AVG_LOSS:1.3225264310836793 -- AVG_ACC:57.7875
# EPOCH:362
# AVG_LOSS:1.2919823765754699 -- AVG_ACC:59.150000000000006
# EPOCH:363
# AVG_LOSS:1.2970772504806518 -- AVG_ACC:59.199999999999996
# EPOCH:364
# AVG_LOSS:1.2957525849342346 -- AVG_ACC:58.5
# EPOCH:365
# AVG_LOSS:1.3052926301956176 -- AVG_ACC:58.45
# EPOCH:366
# AVG_LOSS:1.2943121671676636 -- AVG_ACC:59.175
# EPOCH:367
# AVG_LOSS:1.2939189672470093 -- AVG_ACC:59.262499999999996
# EPOCH:368
# AVG_LOSS:1.2852911949157715 -- AVG_ACC:59.0375
# EPOCH:369
# AVG_LOSS:1.298414659500122 -- AVG_ACC:58.262499999999996
# EPOCH:370
# AVG_LOSS:1.2971189498901368 -- AVG_ACC:59.2875
# EPOCH:371
# AVG_LOSS:1.3020786046981812 -- AVG_ACC:58.925000000000004
# EPOCH:372
# AVG_LOSS:1.2810468554496766 -- AVG_ACC:58.7125
# EPOCH:373
# AVG_LOSS:1.3057761788368225 -- AVG_ACC:58.5125
# EPOCH:374
# AVG_LOSS:1.2982781887054444 -- AVG_ACC:58.8625
# EPOCH:375
# AVG_LOSS:1.2822176694869996 -- AVG_ACC:58.95
# EPOCH:376
# AVG_LOSS:1.3033271908760071 -- AVG_ACC:58.95
# EPOCH:377
# AVG_LOSS:1.284564745426178 -- AVG_ACC:58.7375
# EPOCH:378
# AVG_LOSS:1.2918310523033143 -- AVG_ACC:58.599999999999994
# EPOCH:379
# AVG_LOSS:1.296507215499878 -- AVG_ACC:58.487500000000004
# EPOCH:380
# AVG_LOSS:1.286781096458435 -- AVG_ACC:59.06249999999999
# EPOCH:381
# AVG_LOSS:1.2910356879234315 -- AVG_ACC:58.9
# EPOCH:382
# AVG_LOSS:1.274273419380188 -- AVG_ACC:59.550000000000004
# EPOCH:383
# AVG_LOSS:1.2890052437782287 -- AVG_ACC:58.875
# EPOCH:384
# AVG_LOSS:1.279792594909668 -- AVG_ACC:59.3
# EPOCH:385
# AVG_LOSS:1.2733759999275207 -- AVG_ACC:59.4375
# EPOCH:386
# AVG_LOSS:1.2896906733512878 -- AVG_ACC:59.0
# EPOCH:387
# AVG_LOSS:1.2835125088691712 -- AVG_ACC:58.425000000000004
# EPOCH:388
# AVG_LOSS:1.2774589657783508 -- AVG_ACC:58.95
# EPOCH:389
# AVG_LOSS:1.2942055463790894 -- AVG_ACC:58.262499999999996
# EPOCH:390
# AVG_LOSS:1.2763982892036438 -- AVG_ACC:59.5125
# EPOCH:391
# AVG_LOSS:1.2667142868041992 -- AVG_ACC:59.975
# EPOCH:392
# AVG_LOSS:1.290248155593872 -- AVG_ACC:59.2125
# EPOCH:393
# AVG_LOSS:1.2775095105171204 -- AVG_ACC:59.7375
# EPOCH:394
# AVG_LOSS:1.2724165678024293 -- AVG_ACC:59.599999999999994
# EPOCH:395
# AVG_LOSS:1.2636096715927123 -- AVG_ACC:59.25
# EPOCH:396
# AVG_LOSS:1.2703998327255248 -- AVG_ACC:59.650000000000006
# EPOCH:397
# AVG_LOSS:1.266119694709778 -- AVG_ACC:59.85
# EPOCH:398
# AVG_LOSS:1.2778005003929138 -- AVG_ACC:59.425
# EPOCH:399
# AVG_LOSS:1.279160737991333 -- AVG_ACC:59.2125
# EPOCH:400
# AVG_LOSS:1.2752789855003357 -- AVG_ACC:59.325
# EPOCH:401
# AVG_LOSS:1.284961462020874 -- AVG_ACC:58.8375
# EPOCH:402
# AVG_LOSS:1.2642985343933106 -- AVG_ACC:59.3125
# EPOCH:403
# AVG_LOSS:1.261001455783844 -- AVG_ACC:60.275
# EPOCH:404
# AVG_LOSS:1.283673846721649 -- AVG_ACC:58.975
# EPOCH:405
# AVG_LOSS:1.2716717839241027 -- AVG_ACC:59.262499999999996
# EPOCH:406
# AVG_LOSS:1.2740812063217164 -- AVG_ACC:58.7125
# EPOCH:407
# AVG_LOSS:1.273363971710205 -- AVG_ACC:59.9375
# EPOCH:408
# AVG_LOSS:1.266892910003662 -- AVG_ACC:59.762499999999996
# EPOCH:409
# AVG_LOSS:1.2596068143844605 -- AVG_ACC:59.68750000000001
# EPOCH:410
# AVG_LOSS:1.270559597015381 -- AVG_ACC:59.487500000000004
# EPOCH:411
# AVG_LOSS:1.254357886314392 -- AVG_ACC:60.199999999999996
# EPOCH:412
# AVG_LOSS:1.2591547131538392 -- AVG_ACC:60.212500000000006
# EPOCH:413
# AVG_LOSS:1.264149510860443 -- AVG_ACC:60.199999999999996
# EPOCH:414
# AVG_LOSS:1.2635110139846801 -- AVG_ACC:60.175
# EPOCH:415
# AVG_LOSS:1.267613697052002 -- AVG_ACC:59.599999999999994
# EPOCH:416
# AVG_LOSS:1.265657091140747 -- AVG_ACC:60.0375
# EPOCH:417
# AVG_LOSS:1.2553237199783325 -- AVG_ACC:60.224999999999994
# EPOCH:418
# AVG_LOSS:1.27215918302536 -- AVG_ACC:59.8625
# EPOCH:419
# AVG_LOSS:1.2634692311286926 -- AVG_ACC:59.7125
# EPOCH:420
# AVG_LOSS:1.2572755098342896 -- AVG_ACC:59.9625
# EPOCH:421
# AVG_LOSS:1.244514560699463 -- AVG_ACC:60.425
# EPOCH:422
# AVG_LOSS:1.2823013305664062 -- AVG_ACC:58.825
# EPOCH:423
# AVG_LOSS:1.257153081893921 -- AVG_ACC:60.087500000000006
# EPOCH:424
# AVG_LOSS:1.2486259937286377 -- AVG_ACC:60.087500000000006
# EPOCH:425
# AVG_LOSS:1.256874430179596 -- AVG_ACC:59.425
# EPOCH:426
# AVG_LOSS:1.2669561743736266 -- AVG_ACC:59.650000000000006
# EPOCH:427
# AVG_LOSS:1.2517964601516725 -- AVG_ACC:60.0
# EPOCH:428
# AVG_LOSS:1.2527223944664 -- AVG_ACC:60.0625
# EPOCH:429
# AVG_LOSS:1.2481962203979493 -- AVG_ACC:59.8625
# EPOCH:430
# AVG_LOSS:1.2498913407325745 -- AVG_ACC:60.0625
# EPOCH:431
# AVG_LOSS:1.2525938749313354 -- AVG_ACC:59.875
# EPOCH:432
# AVG_LOSS:1.2491415858268737 -- AVG_ACC:60.3625
# EPOCH:433
# AVG_LOSS:1.2551412224769591 -- AVG_ACC:60.5375
# EPOCH:434
# AVG_LOSS:1.2355754017829894 -- AVG_ACC:60.28750000000001
# EPOCH:435
# AVG_LOSS:1.2403582334518433 -- AVG_ACC:60.62499999999999
# EPOCH:436
# AVG_LOSS:1.2431581139564514 -- AVG_ACC:60.262499999999996
# EPOCH:437
# AVG_LOSS:1.2499159574508667 -- AVG_ACC:60.175
# EPOCH:438
# AVG_LOSS:1.2609923362731934 -- AVG_ACC:59.9125
# EPOCH:439
# AVG_LOSS:1.2347248911857605 -- AVG_ACC:60.575
# EPOCH:440
# AVG_LOSS:1.2506730079650878 -- AVG_ACC:60.4
# EPOCH:441
# AVG_LOSS:1.258592712879181 -- AVG_ACC:60.050000000000004
# EPOCH:442
# AVG_LOSS:1.2459145784378052 -- AVG_ACC:59.724999999999994
# EPOCH:443
# AVG_LOSS:1.2503016591072083 -- AVG_ACC:60.162499999999994
# EPOCH:444
# AVG_LOSS:1.2404703855514527 -- AVG_ACC:60.62499999999999
# EPOCH:445
# AVG_LOSS:1.2529343008995055 -- AVG_ACC:60.0625
# EPOCH:446
# AVG_LOSS:1.2468029022216798 -- AVG_ACC:60.162499999999994
# EPOCH:447
# AVG_LOSS:1.2478089809417725 -- AVG_ACC:60.075
# EPOCH:448
# AVG_LOSS:1.2434247612953186 -- AVG_ACC:61.0125
# EPOCH:449
# AVG_LOSS:1.2303386211395264 -- AVG_ACC:60.762499999999996
# EPOCH:450
# AVG_LOSS:1.237566351890564 -- AVG_ACC:60.099999999999994
# EPOCH:451
# AVG_LOSS:1.254918909072876 -- AVG_ACC:60.224999999999994
# EPOCH:452
# AVG_LOSS:1.2376215934753418 -- AVG_ACC:60.724999999999994
# EPOCH:453
# AVG_LOSS:1.2308129668235779 -- AVG_ACC:60.68750000000001
# EPOCH:454
# AVG_LOSS:1.2679450988769532 -- AVG_ACC:59.325
# EPOCH:455
# AVG_LOSS:1.2418716907501222 -- AVG_ACC:60.099999999999994
# EPOCH:456
# AVG_LOSS:1.2364832997322082 -- AVG_ACC:60.7375
# EPOCH:457
# AVG_LOSS:1.2230493426322937 -- AVG_ACC:61.224999999999994
# EPOCH:458
# AVG_LOSS:1.245072329044342 -- AVG_ACC:60.199999999999996
# EPOCH:459
# AVG_LOSS:1.2413333415985108 -- AVG_ACC:60.28750000000001
# EPOCH:460
# AVG_LOSS:1.2411646842956543 -- AVG_ACC:60.85
# EPOCH:461
# AVG_LOSS:1.2368070006370544 -- AVG_ACC:60.824999999999996
# EPOCH:462
# AVG_LOSS:1.2359896063804627 -- AVG_ACC:60.9625
# EPOCH:463
# AVG_LOSS:1.2306587457656861 -- AVG_ACC:60.724999999999994
# EPOCH:464
# AVG_LOSS:1.2400187015533448 -- AVG_ACC:60.324999999999996
# EPOCH:465
# AVG_LOSS:1.2477236986160278 -- AVG_ACC:59.5375
# EPOCH:466
# AVG_LOSS:1.2404992818832397 -- AVG_ACC:60.224999999999994
# EPOCH:467
# AVG_LOSS:1.2202850341796876 -- AVG_ACC:61.650000000000006
# EPOCH:468
# AVG_LOSS:1.2405980229377747 -- AVG_ACC:60.9625
# EPOCH:469
# AVG_LOSS:1.2288888335227965 -- AVG_ACC:60.8
# EPOCH:470
# AVG_LOSS:1.2256303071975707 -- AVG_ACC:61.150000000000006
# EPOCH:471
# AVG_LOSS:1.2343046188354492 -- AVG_ACC:60.587500000000006
# EPOCH:472
# AVG_LOSS:1.2306309938430786 -- AVG_ACC:60.8375
# EPOCH:473
# AVG_LOSS:1.2353995203971864 -- AVG_ACC:60.762499999999996
# EPOCH:474
# AVG_LOSS:1.2337372064590455 -- AVG_ACC:60.95
# EPOCH:475
# AVG_LOSS:1.2214375853538513 -- AVG_ACC:61.162499999999994
# EPOCH:476
# AVG_LOSS:1.231085228919983 -- AVG_ACC:60.4625
# EPOCH:477
# AVG_LOSS:1.232679843902588 -- AVG_ACC:60.262499999999996
# EPOCH:478
# AVG_LOSS:1.224590790271759 -- AVG_ACC:60.9375
# EPOCH:479
# AVG_LOSS:1.220649254322052 -- AVG_ACC:61.824999999999996
# EPOCH:480
# AVG_LOSS:1.2152822017669678 -- AVG_ACC:61.35
# EPOCH:481
# AVG_LOSS:1.2288416624069214 -- AVG_ACC:60.9
# EPOCH:482
# AVG_LOSS:1.2167475461959838 -- AVG_ACC:61.824999999999996
# EPOCH:483
# AVG_LOSS:1.226593029499054 -- AVG_ACC:61.162499999999994
# EPOCH:484
# AVG_LOSS:1.2264817833900452 -- AVG_ACC:61.2375
# EPOCH:485
# AVG_LOSS:1.2262714982032776 -- AVG_ACC:61.0125
# EPOCH:486
# AVG_LOSS:1.235158920288086 -- AVG_ACC:60.612500000000004
# EPOCH:487
# AVG_LOSS:1.227431845664978 -- AVG_ACC:60.925
# EPOCH:488
# AVG_LOSS:1.2230645775794984 -- AVG_ACC:61.12499999999999
# EPOCH:489
# AVG_LOSS:1.2063413619995118 -- AVG_ACC:61.9125
# EPOCH:490
# AVG_LOSS:1.2306456089019775 -- AVG_ACC:60.762499999999996
# EPOCH:491
# AVG_LOSS:1.2139678955078126 -- AVG_ACC:61.199999999999996
# EPOCH:492
# AVG_LOSS:1.2312200903892516 -- AVG_ACC:60.68750000000001
# EPOCH:493
# AVG_LOSS:1.220611333847046 -- AVG_ACC:61.25000000000001
# EPOCH:494
# AVG_LOSS:1.2371418833732606 -- AVG_ACC:60.68750000000001
# EPOCH:495
# AVG_LOSS:1.2212643265724181 -- AVG_ACC:61.050000000000004
# EPOCH:496
# AVG_LOSS:1.222187304496765 -- AVG_ACC:61.3
# EPOCH:497
# AVG_LOSS:1.219067347049713 -- AVG_ACC:61.075
# EPOCH:498
# AVG_LOSS:1.2122373938560487 -- AVG_ACC:61.212500000000006
# EPOCH:499
# AVG_LOSS:1.2371637344360351 -- AVG_ACC:59.75
# EPOCH:500
# AVG_LOSS:1.223273479938507 -- AVG_ACC:61.175000000000004
# EPOCH:501
# AVG_LOSS:1.2236041665077209 -- AVG_ACC:61.0125
# EPOCH:502
# AVG_LOSS:1.2346763491630555 -- AVG_ACC:60.5375
# EPOCH:503
# AVG_LOSS:1.2130848288536071 -- AVG_ACC:61.68749999999999
# EPOCH:504
# AVG_LOSS:1.2149288773536682 -- AVG_ACC:61.5625
# EPOCH:505
# AVG_LOSS:1.221333646774292 -- AVG_ACC:60.9875
# EPOCH:506
# AVG_LOSS:1.2000690579414368 -- AVG_ACC:62.0875
# EPOCH:507
# AVG_LOSS:1.2159547448158263 -- AVG_ACC:61.75000000000001
# EPOCH:508
# AVG_LOSS:1.1995673060417176 -- AVG_ACC:61.6375
# EPOCH:509
# AVG_LOSS:1.2304515838623047 -- AVG_ACC:60.4125
# EPOCH:510
# AVG_LOSS:1.204255723953247 -- AVG_ACC:61.824999999999996
# EPOCH:511
# AVG_LOSS:1.2077439546585083 -- AVG_ACC:62.0
# EPOCH:512
# AVG_LOSS:1.2137273907661439 -- AVG_ACC:60.975
# EPOCH:513
# AVG_LOSS:1.2075379252433778 -- AVG_ACC:61.4
# EPOCH:514
# AVG_LOSS:1.2021649718284606 -- AVG_ACC:61.550000000000004
# EPOCH:515
# AVG_LOSS:1.2166946411132813 -- AVG_ACC:60.9
# EPOCH:516
# AVG_LOSS:1.2025057077407837 -- AVG_ACC:61.7375
# EPOCH:517
# AVG_LOSS:1.2144365429878234 -- AVG_ACC:61.45
# EPOCH:518
# AVG_LOSS:1.2076812863349915 -- AVG_ACC:61.5
# EPOCH:519
# AVG_LOSS:1.206417155265808 -- AVG_ACC:61.712500000000006
# EPOCH:520
# AVG_LOSS:1.2168299794197082 -- AVG_ACC:61.112500000000004
# EPOCH:521
# AVG_LOSS:1.211311447620392 -- AVG_ACC:61.8375
# EPOCH:522
# AVG_LOSS:1.2155375957489014 -- AVG_ACC:61.575
# EPOCH:523
# AVG_LOSS:1.2130461096763612 -- AVG_ACC:61.762499999999996
# EPOCH:524
# AVG_LOSS:1.2172016382217408 -- AVG_ACC:61.0
# EPOCH:525
# AVG_LOSS:1.2043598771095276 -- AVG_ACC:61.787499999999994
# EPOCH:526
# AVG_LOSS:1.2042588710784912 -- AVG_ACC:61.762499999999996
# EPOCH:527
# AVG_LOSS:1.2143982648849487 -- AVG_ACC:61.525
# EPOCH:528
# AVG_LOSS:1.2152635097503661 -- AVG_ACC:61.625
# EPOCH:529
# AVG_LOSS:1.214849627017975 -- AVG_ACC:61.68749999999999
# EPOCH:530
# AVG_LOSS:1.1969968557357789 -- AVG_ACC:61.8625
# EPOCH:531
# AVG_LOSS:1.1953665375709535 -- AVG_ACC:61.9
# EPOCH:532
# AVG_LOSS:1.2156219244003297 -- AVG_ACC:61.12499999999999
# EPOCH:533
# AVG_LOSS:1.2059800624847412 -- AVG_ACC:62.0625
# EPOCH:534
# AVG_LOSS:1.2028109669685363 -- AVG_ACC:61.525
# EPOCH:535
# AVG_LOSS:1.208998453617096 -- AVG_ACC:61.5125
# EPOCH:536
# AVG_LOSS:1.2087363004684448 -- AVG_ACC:61.0125
# EPOCH:537
# AVG_LOSS:1.1946325182914734 -- AVG_ACC:62.025
# EPOCH:538
# AVG_LOSS:1.2083718180656433 -- AVG_ACC:61.58749999999999
# EPOCH:539
# AVG_LOSS:1.2056745409965515 -- AVG_ACC:61.8125
# EPOCH:540
# AVG_LOSS:1.218131458759308 -- AVG_ACC:61.3625
# EPOCH:541
# AVG_LOSS:1.198757827281952 -- AVG_ACC:61.7375
# EPOCH:542
# AVG_LOSS:1.2047231674194336 -- AVG_ACC:61.787499999999994
# EPOCH:543
# AVG_LOSS:1.2192675948143006 -- AVG_ACC:60.550000000000004
# EPOCH:544
# AVG_LOSS:1.2062608003616333 -- AVG_ACC:61.4375
# EPOCH:545
# AVG_LOSS:1.2126917123794556 -- AVG_ACC:61.1
# EPOCH:546
# AVG_LOSS:1.206308376789093 -- AVG_ACC:61.8125
# EPOCH:547
# AVG_LOSS:1.1944646120071412 -- AVG_ACC:61.662499999999994
# EPOCH:548
# AVG_LOSS:1.2001431465148926 -- AVG_ACC:62.1
# EPOCH:549
# AVG_LOSS:1.2068060398101808 -- AVG_ACC:61.824999999999996
# EPOCH:550
# AVG_LOSS:1.202842652797699 -- AVG_ACC:61.58749999999999
# EPOCH:551
# AVG_LOSS:1.1873897075653077 -- AVG_ACC:62.525
# EPOCH:552
# AVG_LOSS:1.2143499612808228 -- AVG_ACC:61.3
# EPOCH:553
# AVG_LOSS:1.1959718465805054 -- AVG_ACC:62.075
# EPOCH:554
# AVG_LOSS:1.198043656349182 -- AVG_ACC:62.0375
# EPOCH:555
# AVG_LOSS:1.2034123182296752 -- AVG_ACC:61.68749999999999
# EPOCH:556
# AVG_LOSS:1.1961597204208374 -- AVG_ACC:61.68749999999999
# EPOCH:557
# AVG_LOSS:1.2037749409675598 -- AVG_ACC:61.4875
# EPOCH:558
# AVG_LOSS:1.2065630793571471 -- AVG_ACC:61.4
# EPOCH:559
# AVG_LOSS:1.1916279315948486 -- AVG_ACC:62.387499999999996
# EPOCH:560
# AVG_LOSS:1.1890352845191956 -- AVG_ACC:62.0625
# EPOCH:561
# AVG_LOSS:1.2100571632385253 -- AVG_ACC:61.425
# EPOCH:562
# AVG_LOSS:1.1971439123153687 -- AVG_ACC:62.1
# EPOCH:563
# AVG_LOSS:1.2019390225410462 -- AVG_ACC:61.662499999999994
# EPOCH:564
# AVG_LOSS:1.1998176097869873 -- AVG_ACC:61.9375
# EPOCH:565
# AVG_LOSS:1.206051504611969 -- AVG_ACC:62.150000000000006
# EPOCH:566
# AVG_LOSS:1.185835325717926 -- AVG_ACC:62.287499999999994
# EPOCH:567
# AVG_LOSS:1.192524254322052 -- AVG_ACC:61.762499999999996
# EPOCH:568
# AVG_LOSS:1.1901282787322998 -- AVG_ACC:61.925
# EPOCH:569
# AVG_LOSS:1.220012331008911 -- AVG_ACC:60.587500000000006
# EPOCH:570
# AVG_LOSS:1.1975207448005676 -- AVG_ACC:62.050000000000004
# EPOCH:571
# AVG_LOSS:1.1972512245178222 -- AVG_ACC:61.9875
# EPOCH:572
# AVG_LOSS:1.1947283148765564 -- AVG_ACC:61.650000000000006
# EPOCH:573
# AVG_LOSS:1.1932405948638916 -- AVG_ACC:61.9875
# EPOCH:574
# AVG_LOSS:1.1967736840248109 -- AVG_ACC:61.7
# EPOCH:575
# AVG_LOSS:1.1999074459075927 -- AVG_ACC:61.625
# EPOCH:576
# AVG_LOSS:1.1975761890411376 -- AVG_ACC:61.9375
# EPOCH:577
# AVG_LOSS:1.1794980406761169 -- AVG_ACC:62.212500000000006
# EPOCH:578
# AVG_LOSS:1.1827370047569274 -- AVG_ACC:62.150000000000006
# EPOCH:579
# AVG_LOSS:1.1919648408889771 -- AVG_ACC:61.9
# EPOCH:580
# AVG_LOSS:1.1959465503692628 -- AVG_ACC:62.025
# EPOCH:581
# AVG_LOSS:1.195857286453247 -- AVG_ACC:61.724999999999994
# EPOCH:582
# AVG_LOSS:1.195275342464447 -- AVG_ACC:61.9875
# EPOCH:583
# AVG_LOSS:1.1894195675849915 -- AVG_ACC:61.9375
# EPOCH:584
# AVG_LOSS:1.181988823413849 -- AVG_ACC:62.025
# EPOCH:585
# AVG_LOSS:1.2019503355026244 -- AVG_ACC:61.85000000000001
# EPOCH:586
# AVG_LOSS:1.1977035880088807 -- AVG_ACC:61.612500000000004
# EPOCH:587
# AVG_LOSS:1.189988923072815 -- AVG_ACC:61.9875
# EPOCH:588
# AVG_LOSS:1.1924927473068236 -- AVG_ACC:61.712500000000006
# EPOCH:589
# AVG_LOSS:1.1803662657737732 -- AVG_ACC:62.3
# EPOCH:590
# AVG_LOSS:1.198808765411377 -- AVG_ACC:61.675000000000004
# EPOCH:591
# AVG_LOSS:1.1855966210365296 -- AVG_ACC:62.25000000000001
# EPOCH:592
# AVG_LOSS:1.1855198979377746 -- AVG_ACC:62.287499999999994
# EPOCH:593
# AVG_LOSS:1.1787567138671875 -- AVG_ACC:61.9125
# EPOCH:594
# AVG_LOSS:1.1867475986480713 -- AVG_ACC:62.5625
# EPOCH:595
# AVG_LOSS:1.1772039651870727 -- AVG_ACC:62.5125
# EPOCH:596
# AVG_LOSS:1.1869120240211486 -- AVG_ACC:61.787499999999994
# EPOCH:597
# AVG_LOSS:1.207416546344757 -- AVG_ACC:61.9
# EPOCH:598
# AVG_LOSS:1.1713012099266051 -- AVG_ACC:62.4375
# EPOCH:599
# AVG_LOSS:1.182703399658203 -- AVG_ACC:62.5
# EPOCH:600
# AVG_LOSS:1.1903709888458252 -- AVG_ACC:61.9875
# EPOCH:601
# AVG_LOSS:1.2001543641090393 -- AVG_ACC:62.287499999999994
# EPOCH:602
# AVG_LOSS:1.1839959859848022 -- AVG_ACC:62.35000000000001
# EPOCH:603
# AVG_LOSS:1.190743589401245 -- AVG_ACC:62.0375
# EPOCH:604
# AVG_LOSS:1.1785914897918701 -- AVG_ACC:62.0875
# EPOCH:605
# AVG_LOSS:1.1766711354255677 -- AVG_ACC:62.5
# EPOCH:606
# AVG_LOSS:1.185883891582489 -- AVG_ACC:62.1
# EPOCH:607
# AVG_LOSS:1.18317152261734 -- AVG_ACC:62.125
# EPOCH:608
# AVG_LOSS:1.1968903303146363 -- AVG_ACC:61.675000000000004
# EPOCH:609
# AVG_LOSS:1.184786307811737 -- AVG_ACC:62.050000000000004
# EPOCH:610
# AVG_LOSS:1.1846270918846131 -- AVG_ACC:61.925
# EPOCH:611
# AVG_LOSS:1.1814043760299682 -- AVG_ACC:61.95
# EPOCH:612
# AVG_LOSS:1.1950367093086243 -- AVG_ACC:62.0625
# EPOCH:613
# AVG_LOSS:1.1728631973266601 -- AVG_ACC:62.5125
# EPOCH:614
# AVG_LOSS:1.192976462841034 -- AVG_ACC:62.3625
# EPOCH:615
# AVG_LOSS:1.1838680863380433 -- AVG_ACC:62.387499999999996
# EPOCH:616
# AVG_LOSS:1.17400780916214 -- AVG_ACC:62.4375
# EPOCH:617
# AVG_LOSS:1.177316462993622 -- AVG_ACC:62.45
# EPOCH:618
# AVG_LOSS:1.190763485431671 -- AVG_ACC:62.35000000000001
# EPOCH:619
# AVG_LOSS:1.185388696193695 -- AVG_ACC:62.1375
# EPOCH:620
# AVG_LOSS:1.1876869797706604 -- AVG_ACC:62.45
# EPOCH:621
# AVG_LOSS:1.178669798374176 -- AVG_ACC:62.4625
# EPOCH:622
# AVG_LOSS:1.1790641307830811 -- AVG_ACC:62.275000000000006
# EPOCH:623
# AVG_LOSS:1.2015013575553894 -- AVG_ACC:61.5375
# EPOCH:624
# AVG_LOSS:1.1780137538909912 -- AVG_ACC:62.224999999999994
# EPOCH:625
# AVG_LOSS:1.178620707988739 -- AVG_ACC:62.31250000000001
# EPOCH:626
# AVG_LOSS:1.1907257318496705 -- AVG_ACC:62.3375
# EPOCH:627
# AVG_LOSS:1.1891829013824462 -- AVG_ACC:61.824999999999996
# EPOCH:628
# AVG_LOSS:1.1872138619422912 -- AVG_ACC:62.4875
# EPOCH:629
# AVG_LOSS:1.173426592350006 -- AVG_ACC:62.2
# EPOCH:630
# AVG_LOSS:1.193626880645752 -- AVG_ACC:61.762499999999996
# EPOCH:631
# AVG_LOSS:1.162748682498932 -- AVG_ACC:63.0625
# EPOCH:632
# AVG_LOSS:1.1856598496437072 -- AVG_ACC:62.575
# EPOCH:633
# AVG_LOSS:1.1781973600387574 -- AVG_ACC:62.224999999999994
# EPOCH:634
# AVG_LOSS:1.194813895225525 -- AVG_ACC:62.31250000000001
# EPOCH:635
# AVG_LOSS:1.1741090893745423 -- AVG_ACC:62.81250000000001
# EPOCH:636
# AVG_LOSS:1.1734745264053346 -- AVG_ACC:62.737500000000004
# EPOCH:637
# AVG_LOSS:1.186971163749695 -- AVG_ACC:62.050000000000004
# EPOCH:638
# AVG_LOSS:1.1847317934036254 -- AVG_ACC:62.025
# EPOCH:639
# AVG_LOSS:1.1676003336906433 -- AVG_ACC:62.762499999999996
# EPOCH:640
# AVG_LOSS:1.1783998250961303 -- AVG_ACC:62.4625
# EPOCH:641
# AVG_LOSS:1.1705326437950134 -- AVG_ACC:62.5625
# EPOCH:642
# AVG_LOSS:1.1689338326454162 -- AVG_ACC:62.5125
# EPOCH:643
# AVG_LOSS:1.1744773864746094 -- AVG_ACC:62.5
# EPOCH:644
# AVG_LOSS:1.1739209413528442 -- AVG_ACC:62.2
# EPOCH:645
# AVG_LOSS:1.1751795291900635 -- AVG_ACC:62.075
# EPOCH:646
# AVG_LOSS:1.1637730598449707 -- AVG_ACC:62.68749999999999
# EPOCH:647
# AVG_LOSS:1.173230814933777 -- AVG_ACC:62.275000000000006
# EPOCH:648
# AVG_LOSS:1.1757081270217895 -- AVG_ACC:62.525
# EPOCH:649
# AVG_LOSS:1.1804123759269713 -- AVG_ACC:62.0625
# EPOCH:650
# AVG_LOSS:1.1796604871749878 -- AVG_ACC:62.3625
# EPOCH:651
# AVG_LOSS:1.1854645609855652 -- AVG_ACC:62.224999999999994
# EPOCH:652
# AVG_LOSS:1.1647094249725343 -- AVG_ACC:62.81250000000001
# EPOCH:653
# AVG_LOSS:1.1727788209915162 -- AVG_ACC:62.275000000000006
# EPOCH:654
# AVG_LOSS:1.1836318731307984 -- AVG_ACC:62.18749999999999
# EPOCH:655
# AVG_LOSS:1.1833353638648987 -- AVG_ACC:62.824999999999996
# EPOCH:656
# AVG_LOSS:1.1793506383895873 -- AVG_ACC:62.0125
# EPOCH:657
# AVG_LOSS:1.1712845087051391 -- AVG_ACC:62.74999999999999
# EPOCH:658
# AVG_LOSS:1.1744744062423706 -- AVG_ACC:62.1625
# EPOCH:659
# AVG_LOSS:1.1916818857192992 -- AVG_ACC:61.8
# EPOCH:660
# AVG_LOSS:1.17128826379776 -- AVG_ACC:62.262499999999996
# EPOCH:661
# AVG_LOSS:1.1573579788208008 -- AVG_ACC:62.775000000000006
# EPOCH:662
# AVG_LOSS:1.1865017294883728 -- AVG_ACC:62.1
# EPOCH:663
# AVG_LOSS:1.1642334938049317 -- AVG_ACC:62.762499999999996
# EPOCH:664
# AVG_LOSS:1.170390522480011 -- AVG_ACC:62.4125
# EPOCH:665
# AVG_LOSS:1.1772138833999635 -- AVG_ACC:62.849999999999994
# EPOCH:666
# AVG_LOSS:1.175137996673584 -- AVG_ACC:62.3375
# EPOCH:667
# AVG_LOSS:1.167853593826294 -- AVG_ACC:62.5875
# EPOCH:668
# AVG_LOSS:1.172688639163971 -- AVG_ACC:62.81250000000001
# EPOCH:669
# AVG_LOSS:1.1674820065498352 -- AVG_ACC:63.14999999999999
# EPOCH:670
# AVG_LOSS:1.188719058036804 -- AVG_ACC:62.0
# EPOCH:671
# AVG_LOSS:1.1803938269615173 -- AVG_ACC:61.8625
# EPOCH:672
# AVG_LOSS:1.1648179292678833 -- AVG_ACC:62.6375
# EPOCH:673
# AVG_LOSS:1.1752444148063659 -- AVG_ACC:62.612500000000004
# EPOCH:674
# AVG_LOSS:1.1729921340942382 -- AVG_ACC:62.287499999999994
# EPOCH:675
# AVG_LOSS:1.1585792303085327 -- AVG_ACC:62.6625
# EPOCH:676
# AVG_LOSS:1.1930917739868163 -- AVG_ACC:61.9375
# EPOCH:677
# AVG_LOSS:1.160525369644165 -- AVG_ACC:63.224999999999994
# EPOCH:678
# AVG_LOSS:1.1767162322998046 -- AVG_ACC:61.975
# EPOCH:679
# AVG_LOSS:1.1593220472335815 -- AVG_ACC:62.849999999999994
# EPOCH:680
# AVG_LOSS:1.176592230796814 -- AVG_ACC:62.475
# EPOCH:681
# AVG_LOSS:1.1656424283981324 -- AVG_ACC:63.287499999999994
# EPOCH:682
# AVG_LOSS:1.1926642298698424 -- AVG_ACC:62.287499999999994
# EPOCH:683
# AVG_LOSS:1.1820644736289978 -- AVG_ACC:62.35000000000001
# EPOCH:684
# AVG_LOSS:1.1580924034118651 -- AVG_ACC:62.925
# EPOCH:685
# AVG_LOSS:1.1604830741882324 -- AVG_ACC:62.949999999999996
# EPOCH:686
# AVG_LOSS:1.1653228998184204 -- AVG_ACC:62.762499999999996
# EPOCH:687
# AVG_LOSS:1.183345878124237 -- AVG_ACC:62.0375
# EPOCH:688
# AVG_LOSS:1.1827373385429383 -- AVG_ACC:62.075
# EPOCH:689
# AVG_LOSS:1.1686879515647888 -- AVG_ACC:62.1
# EPOCH:690
# AVG_LOSS:1.1570226073265075 -- AVG_ACC:62.9375
# EPOCH:691
# AVG_LOSS:1.1568688869476318 -- AVG_ACC:63.287499999999994
# EPOCH:692
# AVG_LOSS:1.181672990322113 -- AVG_ACC:62.925
# EPOCH:693
# AVG_LOSS:1.1862918376922607 -- AVG_ACC:62.150000000000006
# EPOCH:694
# AVG_LOSS:1.1701195120811463 -- AVG_ACC:62.68749999999999
# EPOCH:695
# AVG_LOSS:1.1606060028076173 -- AVG_ACC:63.0
# EPOCH:696
# AVG_LOSS:1.1661265254020692 -- AVG_ACC:62.824999999999996
# EPOCH:697
# AVG_LOSS:1.1776821732521057 -- AVG_ACC:62.55
# EPOCH:698
# AVG_LOSS:1.1740286588668822 -- AVG_ACC:62.525
# EPOCH:699
# AVG_LOSS:1.1718299984931946 -- AVG_ACC:62.7
# EPOCH:700
# AVG_LOSS:1.1703210711479186 -- AVG_ACC:62.9875
# EPOCH:701
# AVG_LOSS:1.1633806347846984 -- AVG_ACC:62.824999999999996
# EPOCH:702
# AVG_LOSS:1.16634601354599 -- AVG_ACC:62.262499999999996
# EPOCH:703
# AVG_LOSS:1.1658146858215332 -- AVG_ACC:62.425
# EPOCH:704
# AVG_LOSS:1.1649884581565857 -- AVG_ACC:62.4
# EPOCH:705
# AVG_LOSS:1.15107102394104 -- AVG_ACC:62.9625
# EPOCH:706
# AVG_LOSS:1.1657082796096803 -- AVG_ACC:62.6375
# EPOCH:707
# AVG_LOSS:1.1792185306549072 -- AVG_ACC:62.5625
# EPOCH:708
# AVG_LOSS:1.1651321530342102 -- AVG_ACC:62.8375
# EPOCH:709
# AVG_LOSS:1.1682864427566528 -- AVG_ACC:62.5625
# EPOCH:710
# AVG_LOSS:1.1572325229644775 -- AVG_ACC:62.9375
# EPOCH:711
# AVG_LOSS:1.1804226994514466 -- AVG_ACC:62.18749999999999
# EPOCH:712
# AVG_LOSS:1.1668079853057862 -- AVG_ACC:63.125
# EPOCH:713
# AVG_LOSS:1.165863049030304 -- AVG_ACC:62.762499999999996
# EPOCH:714
# AVG_LOSS:1.1711985111236571 -- AVG_ACC:62.425
# EPOCH:715
# AVG_LOSS:1.1632474303245544 -- AVG_ACC:62.6375
# EPOCH:716
# AVG_LOSS:1.162956130504608 -- AVG_ACC:63.1
# EPOCH:717
# AVG_LOSS:1.1621504187583924 -- AVG_ACC:62.787499999999994
# EPOCH:718
# AVG_LOSS:1.1615170598030091 -- AVG_ACC:63.0125
# EPOCH:719
# AVG_LOSS:1.1830488920211792 -- AVG_ACC:62.525
# EPOCH:720
# AVG_LOSS:1.1813414931297301 -- AVG_ACC:62.4375
# EPOCH:721
# AVG_LOSS:1.184937596321106 -- AVG_ACC:62.4
# EPOCH:722
# AVG_LOSS:1.1471978545188903 -- AVG_ACC:63.2
# EPOCH:723
# AVG_LOSS:1.1508227348327638 -- AVG_ACC:62.887499999999996
# EPOCH:724
# AVG_LOSS:1.1781219601631165 -- AVG_ACC:62.150000000000006
# EPOCH:725
# AVG_LOSS:1.1719576835632324 -- AVG_ACC:62.9
# EPOCH:726
# AVG_LOSS:1.1577159881591796 -- AVG_ACC:63.3625
# EPOCH:727
# AVG_LOSS:1.16874520778656 -- AVG_ACC:62.824999999999996
# EPOCH:728
# AVG_LOSS:1.1730334758758545 -- AVG_ACC:62.425
# EPOCH:729
# AVG_LOSS:1.1843738436698914 -- AVG_ACC:62.2
# EPOCH:730
# AVG_LOSS:1.1790680766105652 -- AVG_ACC:62.237500000000004
# EPOCH:731
# AVG_LOSS:1.17211354970932 -- AVG_ACC:62.787499999999994
# EPOCH:732
# AVG_LOSS:1.1644556164741515 -- AVG_ACC:62.6
# EPOCH:733
# AVG_LOSS:1.1558386921882629 -- AVG_ACC:62.9625
# EPOCH:734
# AVG_LOSS:1.1632675528526306 -- AVG_ACC:62.4375
# EPOCH:735
# AVG_LOSS:1.1824467420578002 -- AVG_ACC:62.0125
# EPOCH:736
# AVG_LOSS:1.1544079184532166 -- AVG_ACC:62.975
# EPOCH:737
# AVG_LOSS:1.1602928638458252 -- AVG_ACC:62.824999999999996
# EPOCH:738
# AVG_LOSS:1.1637605667114257 -- AVG_ACC:62.824999999999996
# EPOCH:739
# AVG_LOSS:1.160259747505188 -- AVG_ACC:62.887499999999996
# EPOCH:740
# AVG_LOSS:1.1685000777244567 -- AVG_ACC:62.724999999999994
# EPOCH:741
# AVG_LOSS:1.1851643204689026 -- AVG_ACC:62.2
# EPOCH:742
# AVG_LOSS:1.1759034872055054 -- AVG_ACC:62.5375
# EPOCH:743
# AVG_LOSS:1.1678688883781434 -- AVG_ACC:62.824999999999996
# EPOCH:744
# AVG_LOSS:1.156707751750946 -- AVG_ACC:62.949999999999996
# EPOCH:745
# AVG_LOSS:1.1826683640480042 -- AVG_ACC:62.1
# EPOCH:746
# AVG_LOSS:1.1682562828063965 -- AVG_ACC:62.575
# EPOCH:747
# AVG_LOSS:1.16026873588562 -- AVG_ACC:62.775000000000006
# EPOCH:748
# AVG_LOSS:1.1742889881134033 -- AVG_ACC:62.324999999999996
# EPOCH:749
# AVG_LOSS:1.1689103484153747 -- AVG_ACC:62.762499999999996
# EPOCH:750
# AVG_LOSS:1.1563544273376465 -- AVG_ACC:62.9625
# EPOCH:751
# AVG_LOSS:1.1745532870292663 -- AVG_ACC:62.25000000000001
# EPOCH:752
# AVG_LOSS:1.1669453382492065 -- AVG_ACC:62.8
# EPOCH:753
# AVG_LOSS:1.1656179904937745 -- AVG_ACC:62.3625
# EPOCH:754
# AVG_LOSS:1.1565473318099975 -- AVG_ACC:62.7
# EPOCH:755
# AVG_LOSS:1.1560885906219482 -- AVG_ACC:62.675000000000004
# EPOCH:756
# AVG_LOSS:1.1561055779457092 -- AVG_ACC:62.9875
# EPOCH:757
# AVG_LOSS:1.1754231333732605 -- AVG_ACC:62.625
# EPOCH:758
# AVG_LOSS:1.1662677645683288 -- AVG_ACC:62.887499999999996
# EPOCH:759
# AVG_LOSS:1.1606316447257996 -- AVG_ACC:62.7
# EPOCH:760
# AVG_LOSS:1.1724972009658814 -- AVG_ACC:63.1875
# EPOCH:761
# AVG_LOSS:1.179189956188202 -- AVG_ACC:62.525
# EPOCH:762
# AVG_LOSS:1.1704878687858582 -- AVG_ACC:62.787499999999994
# EPOCH:763
# AVG_LOSS:1.1560238957405091 -- AVG_ACC:62.875
# EPOCH:764
# AVG_LOSS:1.167507779598236 -- AVG_ACC:62.6375
# EPOCH:765
# AVG_LOSS:1.1639447927474975 -- AVG_ACC:62.612500000000004
# EPOCH:766
# AVG_LOSS:1.1674176454544067 -- AVG_ACC:62.425
# EPOCH:767
# AVG_LOSS:1.1761500120162964 -- AVG_ACC:62.275000000000006
# EPOCH:768
# AVG_LOSS:1.1539937138557435 -- AVG_ACC:62.875
# EPOCH:769
# AVG_LOSS:1.175317645072937 -- AVG_ACC:62.925
# EPOCH:770
# AVG_LOSS:1.1696120738983153 -- AVG_ACC:62.81250000000001
# EPOCH:771
# AVG_LOSS:1.171709132194519 -- AVG_ACC:62.3
# EPOCH:772
# AVG_LOSS:1.1481256008148193 -- AVG_ACC:63.14999999999999
# EPOCH:773
# AVG_LOSS:1.1640556693077087 -- AVG_ACC:63.0375
# EPOCH:774
# AVG_LOSS:1.1652785181999206 -- AVG_ACC:63.324999999999996
# EPOCH:775
# AVG_LOSS:1.1558783173561096 -- AVG_ACC:62.949999999999996
# EPOCH:776
# AVG_LOSS:1.156924831867218 -- AVG_ACC:62.712500000000006
# EPOCH:777
# AVG_LOSS:1.1817588210105896 -- AVG_ACC:62.762499999999996
# EPOCH:778
# AVG_LOSS:1.1575353026390076 -- AVG_ACC:62.8625
# EPOCH:779
# AVG_LOSS:1.1618819952011108 -- AVG_ACC:62.8375
# EPOCH:780
# AVG_LOSS:1.1694628834724425 -- AVG_ACC:62.3
# EPOCH:781
# AVG_LOSS:1.1660553574562074 -- AVG_ACC:62.55
# EPOCH:782
# AVG_LOSS:1.1477640986442565 -- AVG_ACC:63.1875
# EPOCH:783
# AVG_LOSS:1.1679206490516663 -- AVG_ACC:62.875
# EPOCH:784
# AVG_LOSS:1.172504448890686 -- AVG_ACC:62.224999999999994
# EPOCH:785
# AVG_LOSS:1.1720225930213928 -- AVG_ACC:62.175000000000004
# EPOCH:786
# AVG_LOSS:1.15551655292511 -- AVG_ACC:63.05
# EPOCH:787
# AVG_LOSS:1.1527064204216004 -- AVG_ACC:62.5125
# EPOCH:788
# AVG_LOSS:1.167776882648468 -- AVG_ACC:62.3375
# EPOCH:789
# AVG_LOSS:1.1495274543762206 -- AVG_ACC:62.824999999999996
# EPOCH:790
# AVG_LOSS:1.166624939441681 -- AVG_ACC:62.775000000000006
# EPOCH:791
# AVG_LOSS:1.1592746734619142 -- AVG_ACC:62.975
# EPOCH:792
# AVG_LOSS:1.1659188985824585 -- AVG_ACC:62.675000000000004
# EPOCH:793
# AVG_LOSS:1.1511611580848693 -- AVG_ACC:63.2
# EPOCH:794
# AVG_LOSS:1.1591387867927552 -- AVG_ACC:62.712500000000006
# EPOCH:795
# AVG_LOSS:1.1791303753852844 -- AVG_ACC:62.375
# EPOCH:796
# AVG_LOSS:1.1627198696136474 -- AVG_ACC:62.762499999999996
# EPOCH:797
# AVG_LOSS:1.181507420539856 -- AVG_ACC:62.18749999999999
# EPOCH:798
# AVG_LOSS:1.1586124897003174 -- AVG_ACC:62.949999999999996
# EPOCH:799
# AVG_LOSS:1.1618240237236024 -- AVG_ACC:62.875
# EPOCH:800
# AVG_LOSS:1.1515402793884277 -- AVG_ACC:62.9625
# EPOCH:801
# AVG_LOSS:1.1629368305206298 -- AVG_ACC:62.5375
# EPOCH:802
# AVG_LOSS:1.1737414956092835 -- AVG_ACC:62.525
# EPOCH:803
# AVG_LOSS:1.1718083143234252 -- AVG_ACC:62.175000000000004
# EPOCH:804
# AVG_LOSS:1.1603362202644347 -- AVG_ACC:62.9
# EPOCH:805
# AVG_LOSS:1.152649462223053 -- AVG_ACC:63.5375
# EPOCH:806
# AVG_LOSS:1.1601727247238158 -- AVG_ACC:62.6375
# EPOCH:807
# AVG_LOSS:1.1694506406784058 -- AVG_ACC:62.9125
# EPOCH:808
# AVG_LOSS:1.1509387373924256 -- AVG_ACC:62.9875
# EPOCH:809
# AVG_LOSS:1.1765705823898316 -- AVG_ACC:62.2
# EPOCH:810
# AVG_LOSS:1.1596513509750366 -- AVG_ACC:63.1
# EPOCH:811
# AVG_LOSS:1.1775810599327088 -- AVG_ACC:63.125
# EPOCH:812
# AVG_LOSS:1.1520268201828003 -- AVG_ACC:62.762499999999996
# EPOCH:813
# AVG_LOSS:1.158088505268097 -- AVG_ACC:62.6625
# EPOCH:814
# AVG_LOSS:1.1565983533859252 -- AVG_ACC:63.41250000000001
# EPOCH:815
# AVG_LOSS:1.1875444531440735 -- AVG_ACC:61.58749999999999
# EPOCH:816
# AVG_LOSS:1.168650734424591 -- AVG_ACC:62.81250000000001
# EPOCH:817
# AVG_LOSS:1.1681411743164063 -- AVG_ACC:62.6625
# EPOCH:818
# AVG_LOSS:1.1551310300827027 -- AVG_ACC:62.8375
# EPOCH:819
# AVG_LOSS:1.1550981760025025 -- AVG_ACC:63.14999999999999
# EPOCH:820
# AVG_LOSS:1.169592559337616 -- AVG_ACC:62.712500000000006
# EPOCH:821
# AVG_LOSS:1.1723461508750916 -- AVG_ACC:62.4625
# EPOCH:822
# AVG_LOSS:1.1553116679191588 -- AVG_ACC:62.849999999999994
# EPOCH:823
# AVG_LOSS:1.1685125827789307 -- AVG_ACC:62.9625
# EPOCH:824
# AVG_LOSS:1.1604551196098327 -- AVG_ACC:62.64999999999999
# EPOCH:825
# AVG_LOSS:1.1581457257270813 -- AVG_ACC:63.14999999999999
# EPOCH:826
# AVG_LOSS:1.160936164855957 -- AVG_ACC:63.075
# EPOCH:827
# AVG_LOSS:1.1479085445404054 -- AVG_ACC:63.0875
# EPOCH:828
# AVG_LOSS:1.151871931552887 -- AVG_ACC:63.0125
# EPOCH:829
# AVG_LOSS:1.1637794375419617 -- AVG_ACC:62.737500000000004
# EPOCH:830
# AVG_LOSS:1.1571343898773194 -- AVG_ACC:63.41250000000001
# EPOCH:831
# AVG_LOSS:1.1706746697425843 -- AVG_ACC:63.025
# EPOCH:832
# AVG_LOSS:1.166446614265442 -- AVG_ACC:63.0375
# EPOCH:833
# AVG_LOSS:1.1601968288421631 -- AVG_ACC:63.287499999999994
# EPOCH:834
# AVG_LOSS:1.1578506827354431 -- AVG_ACC:62.925
# EPOCH:835
# AVG_LOSS:1.1544480443000793 -- AVG_ACC:63.025
# EPOCH:836
# AVG_LOSS:1.1493986248970032 -- AVG_ACC:62.81250000000001
# EPOCH:837
# AVG_LOSS:1.1614821791648864 -- AVG_ACC:62.675000000000004
# EPOCH:838
# AVG_LOSS:1.1699208259582519 -- AVG_ACC:62.8625
# EPOCH:839
# AVG_LOSS:1.1718847513198853 -- AVG_ACC:62.6
# EPOCH:840
# AVG_LOSS:1.1514006018638612 -- AVG_ACC:63.1
# EPOCH:841
# AVG_LOSS:1.1593140006065368 -- AVG_ACC:63.1625
# EPOCH:842
# AVG_LOSS:1.153592085838318 -- AVG_ACC:62.9875
# EPOCH:843
# AVG_LOSS:1.168741273880005 -- AVG_ACC:62.887499999999996
# EPOCH:844
# AVG_LOSS:1.1536587953567505 -- AVG_ACC:63.2
# EPOCH:845
# AVG_LOSS:1.1469510197639465 -- AVG_ACC:63.2
# EPOCH:846
# AVG_LOSS:1.1556527256965636 -- AVG_ACC:62.7
# EPOCH:847
# AVG_LOSS:1.1569371104240418 -- AVG_ACC:62.8375
# EPOCH:848
# AVG_LOSS:1.1538585066795348 -- AVG_ACC:62.5875
# EPOCH:849
# AVG_LOSS:1.1767579197883606 -- AVG_ACC:62.625
# EPOCH:850
# AVG_LOSS:1.1694875478744506 -- AVG_ACC:62.9625
# EPOCH:851
# AVG_LOSS:1.1545334815979005 -- AVG_ACC:63.5375
# EPOCH:852
# AVG_LOSS:1.153627061843872 -- AVG_ACC:62.8625
# EPOCH:853
# AVG_LOSS:1.1707671761512757 -- AVG_ACC:62.675000000000004
# EPOCH:854
# AVG_LOSS:1.143468964099884 -- AVG_ACC:63.3
# EPOCH:855
# AVG_LOSS:1.1709837555885314 -- AVG_ACC:62.9375
# EPOCH:856
# AVG_LOSS:1.1613775491714478 -- AVG_ACC:62.68749999999999
# EPOCH:857
# AVG_LOSS:1.1540940642356872 -- AVG_ACC:63.0375
# EPOCH:858
# AVG_LOSS:1.1702435493469239 -- AVG_ACC:62.9
# EPOCH:859
# AVG_LOSS:1.1550005793571472 -- AVG_ACC:62.9375
# EPOCH:860
# AVG_LOSS:1.167417061328888 -- AVG_ACC:63.0125
# EPOCH:861
# AVG_LOSS:1.168482744693756 -- AVG_ACC:63.175000000000004
# EPOCH:862
# AVG_LOSS:1.1527685523033142 -- AVG_ACC:63.0125
# EPOCH:863
# AVG_LOSS:1.15605171918869 -- AVG_ACC:63.0625
# EPOCH:864
# AVG_LOSS:1.1661294221878051 -- AVG_ACC:62.762499999999996
# EPOCH:865
# AVG_LOSS:1.141408956050873 -- AVG_ACC:63.375
# EPOCH:866
# AVG_LOSS:1.1467154264450072 -- AVG_ACC:63.2625
# EPOCH:867
# AVG_LOSS:1.1613669633865356 -- AVG_ACC:62.824999999999996
# EPOCH:868
# AVG_LOSS:1.157296597957611 -- AVG_ACC:62.949999999999996
# EPOCH:869
# AVG_LOSS:1.1675151944160462 -- AVG_ACC:62.8
# EPOCH:870
# AVG_LOSS:1.1652971506118774 -- AVG_ACC:63.14999999999999
# EPOCH:871
# AVG_LOSS:1.152058756351471 -- AVG_ACC:62.9625
# EPOCH:872
# AVG_LOSS:1.169385313987732 -- AVG_ACC:62.4125
# EPOCH:873
# AVG_LOSS:1.1579556226730348 -- AVG_ACC:62.975
# EPOCH:874
# AVG_LOSS:1.1495450496673585 -- AVG_ACC:62.9875
# EPOCH:875
# AVG_LOSS:1.1616099238395692 -- AVG_ACC:62.7
# EPOCH:876
# AVG_LOSS:1.1657400727272034 -- AVG_ACC:62.675000000000004
# EPOCH:877
# AVG_LOSS:1.1657703399658204 -- AVG_ACC:62.925
# EPOCH:878
# AVG_LOSS:1.1672570824623107 -- AVG_ACC:63.1625
# EPOCH:879
# AVG_LOSS:1.1511808276176452 -- AVG_ACC:63.0875
# EPOCH:880
# AVG_LOSS:1.1671688675880432 -- AVG_ACC:62.787499999999994
# EPOCH:881
# AVG_LOSS:1.1549197852611541 -- AVG_ACC:62.9375
# EPOCH:882
# AVG_LOSS:1.1646520495414734 -- AVG_ACC:62.9
# EPOCH:883
# AVG_LOSS:1.1647474884986877 -- AVG_ACC:62.775000000000006
# EPOCH:884
# AVG_LOSS:1.159080982208252 -- AVG_ACC:62.824999999999996
# EPOCH:885
# AVG_LOSS:1.1409063458442688 -- AVG_ACC:63.31250000000001
# EPOCH:886
# AVG_LOSS:1.1621661067008973 -- AVG_ACC:63.31250000000001
# EPOCH:887
# AVG_LOSS:1.1590620040893556 -- AVG_ACC:63.2
# EPOCH:888
# AVG_LOSS:1.1692025065422058 -- AVG_ACC:63.075
# EPOCH:889
# AVG_LOSS:1.1668453335762023 -- AVG_ACC:63.0375
# EPOCH:890
# AVG_LOSS:1.1394383907318115 -- AVG_ACC:63.475
# EPOCH:891
# AVG_LOSS:1.1624218463897704 -- AVG_ACC:63.0
# EPOCH:892
# AVG_LOSS:1.1597373008728027 -- AVG_ACC:62.9875
# EPOCH:893
# AVG_LOSS:1.150742769241333 -- AVG_ACC:63.4875
# EPOCH:894
# AVG_LOSS:1.1612781882286072 -- AVG_ACC:63.237500000000004
# EPOCH:895
# AVG_LOSS:1.1705634236335754 -- AVG_ACC:62.5375
# EPOCH:896
# AVG_LOSS:1.1584009051322937 -- AVG_ACC:62.4875
# EPOCH:897
# AVG_LOSS:1.170785367488861 -- AVG_ACC:62.4
# EPOCH:898
# AVG_LOSS:1.164449965953827 -- AVG_ACC:63.1
# EPOCH:899
# AVG_LOSS:1.1730846047401429 -- AVG_ACC:62.4875
# EPOCH:900
# AVG_LOSS:1.158233392238617 -- AVG_ACC:63.025
# EPOCH:901
# AVG_LOSS:1.159052300453186 -- AVG_ACC:62.9375
# EPOCH:902
# AVG_LOSS:1.1667512655258179 -- AVG_ACC:62.68749999999999
# EPOCH:903
# AVG_LOSS:1.1576058745384217 -- AVG_ACC:63.0875
# EPOCH:904
# AVG_LOSS:1.1625560522079468 -- AVG_ACC:63.237500000000004
# EPOCH:905
# AVG_LOSS:1.1499951481819153 -- AVG_ACC:63.075
# EPOCH:906
# AVG_LOSS:1.1712950468063354 -- AVG_ACC:62.975
# EPOCH:907
# AVG_LOSS:1.167464005947113 -- AVG_ACC:63.0125
# EPOCH:908
# AVG_LOSS:1.1508408546447755 -- AVG_ACC:63.14999999999999
# EPOCH:909
# AVG_LOSS:1.1666778087615968 -- AVG_ACC:62.68749999999999
# EPOCH:910
# AVG_LOSS:1.1575658917427063 -- AVG_ACC:63.0875
# EPOCH:911
# AVG_LOSS:1.1602648735046386 -- AVG_ACC:62.887499999999996
# EPOCH:912
# AVG_LOSS:1.1544981479644776 -- AVG_ACC:63.14999999999999
# EPOCH:913
# AVG_LOSS:1.161936640739441 -- AVG_ACC:63.1625
# EPOCH:914
# AVG_LOSS:1.1471816182136536 -- AVG_ACC:63.2625
# EPOCH:915
# AVG_LOSS:1.182716393470764 -- AVG_ACC:62.31250000000001
# EPOCH:916
# AVG_LOSS:1.1733036756515502 -- AVG_ACC:62.887499999999996
# EPOCH:917
# AVG_LOSS:1.1568002343177795 -- AVG_ACC:63.375
# EPOCH:918
# AVG_LOSS:1.1669456243515015 -- AVG_ACC:62.737500000000004
# EPOCH:919
# AVG_LOSS:1.1541876792907715 -- AVG_ACC:63.0875
# EPOCH:920
# AVG_LOSS:1.167359721660614 -- AVG_ACC:62.787499999999994
# EPOCH:921
# AVG_LOSS:1.1600046277046203 -- AVG_ACC:63.41250000000001
# EPOCH:922
# AVG_LOSS:1.1531269907951356 -- AVG_ACC:63.6
# EPOCH:923
# AVG_LOSS:1.1561760783195496 -- AVG_ACC:63.4875
# EPOCH:924
# AVG_LOSS:1.1652811169624329 -- AVG_ACC:62.712500000000006
# EPOCH:925
# AVG_LOSS:1.168214499950409 -- AVG_ACC:62.8375
# EPOCH:926
# AVG_LOSS:1.163387405872345 -- AVG_ACC:62.925
# EPOCH:927
# AVG_LOSS:1.1646211862564086 -- AVG_ACC:62.887499999999996
# EPOCH:928
# AVG_LOSS:1.165443778038025 -- AVG_ACC:62.8
# EPOCH:929
# AVG_LOSS:1.1631021857261659 -- AVG_ACC:62.975
# EPOCH:930
# AVG_LOSS:1.1620686292648315 -- AVG_ACC:63.324999999999996
# EPOCH:931
# AVG_LOSS:1.1667156934738159 -- AVG_ACC:63.1875
# EPOCH:932
# AVG_LOSS:1.1824556946754456 -- AVG_ACC:62.887499999999996
# EPOCH:933
# AVG_LOSS:1.1742554306983948 -- AVG_ACC:63.324999999999996
# EPOCH:934
# AVG_LOSS:1.1470414638519286 -- AVG_ACC:63.725
# EPOCH:935
# AVG_LOSS:1.1718828201293945 -- AVG_ACC:62.9
# EPOCH:936
# AVG_LOSS:1.1580519437789918 -- AVG_ACC:62.9375
# EPOCH:937
# AVG_LOSS:1.174801754951477 -- AVG_ACC:62.724999999999994
# EPOCH:938
# AVG_LOSS:1.1560681819915772 -- AVG_ACC:63.5125
# EPOCH:939
# AVG_LOSS:1.1503201246261596 -- AVG_ACC:63.7
# EPOCH:940
# AVG_LOSS:1.162015175819397 -- AVG_ACC:63.324999999999996
# EPOCH:941
# AVG_LOSS:1.1555375576019287 -- AVG_ACC:63.24999999999999
# EPOCH:942
# AVG_LOSS:1.1640042185783386 -- AVG_ACC:63.275000000000006
# EPOCH:943
# AVG_LOSS:1.1579650282859801 -- AVG_ACC:63.324999999999996
# EPOCH:944
# AVG_LOSS:1.1568446516990663 -- AVG_ACC:63.349999999999994
# EPOCH:945
# AVG_LOSS:1.1639986753463745 -- AVG_ACC:63.0625
# EPOCH:946
# AVG_LOSS:1.156384241580963 -- AVG_ACC:63.41250000000001
# EPOCH:947
# AVG_LOSS:1.1550699114799499 -- AVG_ACC:63.65
# EPOCH:948
# AVG_LOSS:1.170727276802063 -- AVG_ACC:62.9625
# EPOCH:949
# AVG_LOSS:1.1630273818969727 -- AVG_ACC:63.2
# EPOCH:950
# AVG_LOSS:1.1494479298591613 -- AVG_ACC:63.74999999999999
# EPOCH:951
# AVG_LOSS:1.1630923390388488 -- AVG_ACC:63.3
# EPOCH:952
# AVG_LOSS:1.1601919412612915 -- AVG_ACC:63.4375
# EPOCH:953
# AVG_LOSS:1.1446911215782165 -- AVG_ACC:63.475
# EPOCH:954
# AVG_LOSS:1.162689781188965 -- AVG_ACC:63.175000000000004
# EPOCH:955
# AVG_LOSS:1.1634749174118042 -- AVG_ACC:62.975
# EPOCH:956
# AVG_LOSS:1.1795377731323242 -- AVG_ACC:62.775000000000006
# EPOCH:957
# AVG_LOSS:1.157677662372589 -- AVG_ACC:63.349999999999994
# EPOCH:958
# AVG_LOSS:1.1591357469558716 -- AVG_ACC:63.237500000000004
# EPOCH:959
# AVG_LOSS:1.1630714774131774 -- AVG_ACC:63.0875
# EPOCH:960
# AVG_LOSS:1.141582429409027 -- AVG_ACC:63.8625
# EPOCH:961
# AVG_LOSS:1.1544680953025819 -- AVG_ACC:63.5375
# EPOCH:962
# AVG_LOSS:1.1588126063346862 -- AVG_ACC:63.31250000000001
# EPOCH:963
# AVG_LOSS:1.1499965071678162 -- AVG_ACC:63.2625
# EPOCH:964
# AVG_LOSS:1.1806043148040772 -- AVG_ACC:62.787499999999994
# EPOCH:965
# AVG_LOSS:1.1609605431556702 -- AVG_ACC:63.275000000000006
# EPOCH:966
# AVG_LOSS:1.1536506056785583 -- AVG_ACC:63.2625
# EPOCH:967
# AVG_LOSS:1.1702793478965758 -- AVG_ACC:62.787499999999994
# EPOCH:968
# AVG_LOSS:1.1598408102989197 -- AVG_ACC:63.125
# EPOCH:969
# AVG_LOSS:1.1505722522735595 -- AVG_ACC:63.375
# EPOCH:970
# AVG_LOSS:1.1886774182319642 -- AVG_ACC:62.287499999999994
# EPOCH:971
# AVG_LOSS:1.1653802156448365 -- AVG_ACC:62.925
# EPOCH:972
# AVG_LOSS:1.166049063205719 -- AVG_ACC:63.0625
# EPOCH:973
# AVG_LOSS:1.17002592086792 -- AVG_ACC:62.9875
# EPOCH:974
# AVG_LOSS:1.151904535293579 -- AVG_ACC:63.5625
# EPOCH:975
# AVG_LOSS:1.1706372261047364 -- AVG_ACC:62.875
# EPOCH:976
# AVG_LOSS:1.1915544748306275 -- AVG_ACC:62.4375
# EPOCH:977
# AVG_LOSS:1.1480655789375305 -- AVG_ACC:63.7
# EPOCH:978
# AVG_LOSS:1.1508707880973816 -- AVG_ACC:63.9875
# EPOCH:979
# AVG_LOSS:1.1764977812767028 -- AVG_ACC:62.74999999999999
# EPOCH:980
# AVG_LOSS:1.1678014278411866 -- AVG_ACC:62.9875
# EPOCH:981
# AVG_LOSS:1.1685051918029785 -- AVG_ACC:62.875
# EPOCH:982
# AVG_LOSS:1.149572741985321 -- AVG_ACC:63.800000000000004
# EPOCH:983
# AVG_LOSS:1.1671142339706422 -- AVG_ACC:63.0625
# EPOCH:984
# AVG_LOSS:1.151559019088745 -- AVG_ACC:63.612500000000004
# EPOCH:985
# AVG_LOSS:1.1440181374549865 -- AVG_ACC:63.824999999999996
# EPOCH:986
# AVG_LOSS:1.1740034341812133 -- AVG_ACC:62.6375
# EPOCH:987
# AVG_LOSS:1.1575878024101258 -- AVG_ACC:63.3
# EPOCH:988
# AVG_LOSS:1.1645804524421692 -- AVG_ACC:63.112500000000004
# EPOCH:989
# AVG_LOSS:1.1613029003143311 -- AVG_ACC:63.1375
# EPOCH:990
# AVG_LOSS:1.1557470917701722 -- AVG_ACC:63.287499999999994
# EPOCH:991
# AVG_LOSS:1.164861297607422 -- AVG_ACC:62.9125
# EPOCH:992
# AVG_LOSS:1.153672695159912 -- AVG_ACC:63.31250000000001
# EPOCH:993
# AVG_LOSS:1.1804234385490417 -- AVG_ACC:62.975
# EPOCH:994
# AVG_LOSS:1.1587464928627014 -- AVG_ACC:63.625
# EPOCH:995
# AVG_LOSS:1.1615538001060486 -- AVG_ACC:63.41250000000001
# EPOCH:996
# AVG_LOSS:1.172817325592041 -- AVG_ACC:63.275000000000006
# EPOCH:997
# AVG_LOSS:1.1622276306152344 -- AVG_ACC:63.24999999999999
# EPOCH:998
# AVG_LOSS:1.161063015460968 -- AVG_ACC:63.787499999999994
# EPOCH:999
# AVG_LOSS:1.1683700680732727 -- AVG_ACC:63.2625
# EPOCH:1000
# AVG_LOSS:1.1613135814666748 -- AVG_ACC:63.14999999999999
# DONE!
# BEST_ACC: 63.9875
# Do you want to save the model? [y/n]:y

# %%
fig, (ax1,ax2) = plt.subplots(1,2)
fig.suptitle('LOSS X ACCURACY')
ax1.plot(losses)
ax1.set_title('LOSS\EPOCH')
ax1.set(xlabel='EPOCH',ylabel='LOSS')
ax2.plot(accs)
ax2.set_title('ACCURACY\EPOCH')
ax2.set(xlabel='EPOCH',ylabel='ACCURACY')
# Out:
# [Text(0.5, 0, 'EPOCH'), Text(0, 0.5, 'ACCURACY')]

# %%
def validate_best_model(dataloader,model):
  global DEVICE, encoder
  all_preds = []
  all_y = []
  classes_array = [0] * len(encoder.categories_[0])
  classes_false_array = [0] * len(encoder.categories_[0])

  model.eval()
  with torch.no_grad():
    for X, y in dataloader:
      X, y = X.to(DEVICE), y.to(DEVICE)
      logits = model(X)
      preds = torch.softmax(logits,dim=1).argmax(dim=1)
      all_preds.append(preds)
      all_y.append(y)
    all_preds = torch.cat(all_preds)
    all_y = torch.cat(all_y).argmax(dim=1)
    for index, target in enumerate(all_y):
      if target == all_preds[index]:
        classes_array[target] += 1
      else:
        classes_false_array[target] +=1

    X = encoder.categories_[0]
    X_axis = np.arange(len(X))
    plt.bar(X_axis - 0.2, classes_array, 0.4, label = 'Correct Preds')
    plt.bar(X_axis + 0.2, classes_false_array, 0.4, label = 'Incorrect Preds')

    plt.xticks(X_axis, X)
    plt.tick_params(labelrotation=90)
    plt.xlabel('Categories')
    plt.ylabel('Number of Preds')
    plt.title('Correct and Incorrect Preds in each Categorie')
    plt.legend()
    plt.show()

# %%
validate_best_model(test_dataloader,model)
